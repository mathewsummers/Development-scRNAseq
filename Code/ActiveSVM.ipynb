# %% [markdown]
# ## ActiveSVM
# Notebook to implement activeSVM iterative gene panel selection
#
# https://www.nature.com/articles/s43588-022-00263-8
# https://github.com/xqchen/activeSVC

# %%
import numpy as np
import time
import random
import os

from sklearn.preprocessing import normalize 
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
from matplotlib import gridspec

from activeSVC import min_complexity, min_acquisition
import pandas as pd
import pickle
import os, psutil
import resource

import anndata as ad
import scanpy as sc


def text_create(path, name, msg):
    full_path = path + "/" + name + '.pickle'
    f=open(full_path,'wb') 
    pickle.dump(msg,f)
    f.close()

class TimerError(Exception):
     """A custom exception used to report errors in use of Timer class"""

class Timer:
    def __init__(self):
        self._start_time = None

    def start(self):
        if self._start_time is not None:
            raise TimerError(f"Timer is running. Use .stop() to stop it")

        self._start_time = time.perf_counter()

    def stop(self):
        if self._start_time is None:
            raise TimerError(f"Timer is not running. Use .start() to start it")

        elapsed_time = time.perf_counter() - self._start_time
        self._start_time = None
        print(f"Total run time: {elapsed_time:0.4f} seconds")
        return elapsed_time

# %% [markdown]
# ## Load and split data

# %%
# Load in pre-processed data from glutamatergic class designation, subclass to all rank_gene_groups already performed
gluData = sc.read("../Data/clusterData.h5ad")

with open("../Data/shortGenes.pickle", "rb") as f:
    shortGenes = pickle.load(f)
    
# Remove genes likely to be too short for MERSCOPE
keepGenes = list(set(gluData.var_names) - set(shortGenes))
gluData = gluData[:,keepGenes]
# Out:
# /opt/conda/lib/python3.7/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
# Subset data
# Load in pre-processed data from glutamatergic class designation, subclass to all rank_gene_groups already performed
data = normalize(gluData.X,axis=1, norm="l2")
target = pd.Categorical(gluData.obs["cluster_label"]).codes
keys = pd.Categorical(gluData.obs["cluster_label"]).categories

idx = np.arange(np.shape(data)[0])
random.shuffle(idx)
X_train = data[idx[:int(np.shape(data)[0]*4/5)],:]
y_train = target[idx[:int(np.shape(data)[0]*4/5)]]
X_test = data[idx[int(np.shape(data)[0]*4/5):],:]
y_test = target[idx[int(np.shape(data)[0]*4/5):]]

print(type(data))
print(np.shape(data),np.shape(target),len(np.unique(target)))
print(np.shape(X_train))
print(np.shape(X_test))
for i in np.unique(target):
    print('class '+keys[i]+': '+str(np.count_nonzero((target==i)*1)))
# Out:
# <class 'scipy.sparse.csr.csr_matrix'>
# (62784, 26589) (62784,) 101
# (50227, 26589)
# (12557, 26589)
# class 100_Rxfp1 Epb4_RE: 35
# class 101_Rxfp1 Epb4_RE: 226
# class 102_Rxfp1 Epb4_MG-SPFp-PP-POL-SGN-PoT-PIL: 57
# class 103_Rxfp1 Epb4_MG-SPFp-PP-POL-SGN-PoT-PIL: 57
# class 104_Rxfp1 Epb4_VPMpc-VPLpc: 110
# class 105_Rxfp1 Epb4_VPMpc-VPLpc: 71
# class 106_Rxfp1 Epb4_POL-SGN: 51
# class 107_Rxfp1 Epb4_LP: 72
# class 108_Rxfp1 Epb4_LP: 50
# class 109_Prkcd Grin2c_LP: 168
# class 10_MHb_Tac1 Wif1: 89
# class 110_Rxfp1 Epb4_IMD-PVT: 270
# class 111_Rxfp1 Epb4_IMD-CM: 2244
# class 112_Rxfp1 Epb4_PCN-CM: 524
# class 113_Rxfp1 Epb4_PCN-CM: 809
# class 114_Rxfp1 Epb4_PCN-CM: 453
# class 116_Rxfp1 Epb4_POL: 406
# class 117_Rxfp1 Epb4_PCN-SPFp: 518
# class 118_Rxfp1 Epb4_PVT-IMD: 1998
# class 119_Rxfp1 Epb4_IMD-CM-CL: 1783
# class 11_MHb_Tac1 Wif1: 282
# class 120_Prkcd Grin2c_LP-(midbrain-area-between-LP-LH): 1592
# class 121_Prkcd Grin2c_CL-LP-PO-(a-to-p-multiple-nuclei): 527
# class 122_Prkcd Grin2c_MD: 3562
# class 123_Prkcd Grin2c_LP-POL: 300
# class 124_Prkcd Grin2c_IMD: 136
# class 125_Prkcd Grin2c_AM: 4260
# class 126_Prkcd Grin2c_VM-AM: 3364
# class 127_Prkcd Grin2c_PCN: 352
# class 128_Prkcd Grin2c_LD: 60
# class 129_Prkcd Grin2c_LD: 913
# class 12_MHb_Tac1 Wif1: 231
# class 130_Prkcd Grin2c_LD: 4591
# class 131_Prkcd Grin2c_LGN: 101
# class 132_Prkcd Grin2c_LP: 94
# class 133_Prkcd Grin2c_Broad: 591
# class 134_Prkcd Grin2c_Broad: 860
# class 135_Prkcd Grin2c_VAL-PO: 1765
# class 136_Prkcd Grin2c_LP: 963
# class 137_Prkcd Grin2c_PCN: 67
# class 138_Prkcd Grin2c_LP-PO-POL-SGN-Eth-(Lateral-group-of-dorsal-thalamus): 4690
# class 139_Prkcd Grin2c_POL: 60
# class 13_MHb_Tac1 Wif1: 1109
# class 140_AV_Col27a1 Npsr1: 722
# class 141_AV_Col27a1 Npsr1: 613
# class 14_MHb_Tac1 Neurod2: 474
# class 15_HbX_Klhl4 Sst: 104
# class 16_HbX_Klhl4 Sst: 184
# class 17_HbX_Klhl4 Sst: 139
# class 18_LHb_Klhl4 Wif1: 202
# class 19_LHb_Klhl4 Wif1: 219
# class 1_MHb_Chat Chrnb3: 870
# class 20_LHb_Klhl4 Wif1: 92
# class 2_MHb_Chat Chrnb3: 1264
# class 3_MHb_Chat Chrnb3: 448
# class 4_MHb_Chat Chrnb3: 442
# class 57_Rprml Zim1_LH PVT: 36
# class 58_Rprml Zim1_LGv: 55
# class 59_Rprml Zim1_LH PVT: 63
# class 5_MHb_Chat Chrnb3: 162
# class 61_Rprml Zim1_IMD: 84
# class 62_Rprml Zim1_LH VPM: 197
# class 63_Rprml Zim1_CM: 11
# class 64_Rprml Zim1_CM: 26
# class 65_Rprml Zim1_CM IMD: 15
# class 66_Rprml Zim1_CM PCN: 30
# class 67_Rprml Zim1_PCN: 16
# class 68_Rprml Zim1_IMD: 2927
# class 6_MHb_Chat Chrnb3: 33
# class 70_Rprml Zim1_SPA IMD: 123
# class 71_Rprml Zim1_SPA: 12
# class 72_LHb_Sod3: 49
# class 73_LHb_Sod3: 252
# class 74_LHb_Sod3: 122
# class 75_LHb_Fgd5 Cdh9: 1046
# class 77_LHb_Fgd5 Cdh9: 163
# class 78_LHb_Fgd5 Cdh9: 73
# class 79_PF_Pdyn Kcnj5: 241
# class 7_MHb_Chat Tnfaip2 Nxph4: 585
# class 80_PF_Pdyn Kcnj5: 167
# class 81_PF_Pdyn Kcnj5: 24
# class 82_PF_Pdyn Kcnj5: 492
# class 83_PF_Pdyn Kcnj5: 249
# class 84_PF_Pdyn Kcnj5: 2049
# class 85_PF_Gcm2 Sycp2l: 78
# class 86_PF_Gcm2 Sycp2l: 74
# class 87_PF_Gcm2 Sycp2l: 255
# class 88_PF_Gcm2 Sycp2l: 75
# class 89_PVT_Tnfaip8l3 Peg10: 298
# class 8_MHb_Chat Tnfaip2 Nxph4: 83
# class 90_PVT_Tnfaip8l3 Peg10: 859
# class 91_PVT_Tnfaip8l3 Peg10: 210
# class 92_PVT-posterio_Lgals3 Drd2: 352
# class 93_PVT-posterio_Lgals3 Drd2: 2950
# class 94_PVT_Lgals3 Drd2: 83
# class 95_PVT_Lgals3 Drd2: 251
# class 96_AD_C1ql2: 861
# class 97_Rxfp1 Epb4_PVT-IMD: 224
# class 98_Rxfp1 Epb4_PVT: 294
# class 99_Rxfp1 Epb4_RE: 208
# class 9_MHb_Tac1 Wif1: 93

# %% [markdown]
# ## Setup parameters

# %%
'''
Parameters
'''
num_features = 500
num_samples=20
init_samples=100
balance=False
gene = gluData.var_names

folder='../Data/activeSVM'
path=folder+'/cluster_'+str(num_features)+'_'+str(num_samples)

try:
    os.mkdir('results')
except OSError:
    print ("Creation of the directory %s failed" % 'results')
else:
    print ("Successfully created the directory %s " % 'results')
try:
    os.mkdir(folder)
except OSError:
    print ("Creation of the directory %s failed" % folder)
else:
    print ("Successfully created the directory %s " % folder)
try:
    os.mkdir(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)
# Out:
# Creation of the directory results failed
# Creation of the directory ../Data/activeSVM failed
# Creation of the directory ../Data/activeSVM/cluster_500_20 failed

# %% [markdown]
# ## Select genes

# %%
if __name__ == '__main__':

    t=Timer()
    t.start()
    feature_selected, num_samples_list, train_errors,test_errors,train_scores,test_scores, step_times= min_complexity(
        X_train,y_train,X_test,y_test,num_features=num_features,num_samples=num_samples,init_samples=init_samples, balance=balance, max_iter=1000)
    elapsed_time=t.stop()
    
    memorys=[]
    memorys.append(psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)
    memorys.append(resource.getrusage(resource.RUSAGE_SELF).ru_maxrss/ 1024 ** 2)
    
    text_create(path,'feature_selected',feature_selected)
    text_create(path,'error',train_errors+test_errors)
    text_create(path,'accuracy',train_scores+test_scores)
    text_create(path,'num_samples_list',num_samples_list)
    text_create(path,'genes_name',gene[feature_selected])
    text_create(path,'elapsed_time',elapsed_time)
    text_create(path,'memory',memorys)
# Out:
# Elapsed time: 20.8551 seconds
# feature 0 : gene [0]  100 samples
# training error=-3.989885917932586 test error=-3.2349287250139365
# training accuracy=0.07466103888346905 test accuracy=0.07565501314008123
# Elapsed time: 10.4762 seconds
# feature 1 : gene 1  120 samples
# training error=-3.989885917932586 test error=-3.2349287250139365
# training accuracy=0.07466103888346905 test accuracy=0.07565501314008123
# Elapsed time: 10.3021 seconds
# feature 2 : gene 2  140 samples
# training error=2.9959185298743702 test error=3.7508162777733536
# training accuracy=0.08726382224699862 test accuracy=0.08847654694592658
# Elapsed time: 11.0534 seconds
# feature 3 : gene 13846  160 samples
# training error=-0.2837119477571824 test error=-0.20028669268137295
# training accuracy=0.09522766639456866 test accuracy=0.09070637891216055
# Elapsed time: 11.5704 seconds
# feature 4 : gene 7496  180 samples
# training error=-3.051326975531089 test error=-3.7596559687823525
# training accuracy=0.13156270531785694 test accuracy=0.12526877438878714
# Elapsed time: 12.6181 seconds
# feature 5 : gene 23255  200 samples
# training error=0.7947319170963825 test error=0.18499641634148284
# training accuracy=0.15621080295458617 test accuracy=0.15091184200047783
# Elapsed time: 13.2339 seconds
# feature 6 : gene 25652  220 samples
# training error=3.1691321400840184 test error=2.640678506012583
# training accuracy=0.1875883488960121 test accuracy=0.18212948952775346
# Elapsed time: 13.5638 seconds
# feature 7 : gene 16683  240 samples
# training error=1.9204212873554065 test error=1.57880066894959
# training accuracy=0.20540745017620005 test accuracy=0.1960659393167158
# Elapsed time: 14.0734 seconds
# feature 8 : gene 11288  260 samples
# training error=0.47667589145280426 test error=-0.01640519232300709
# training accuracy=0.23320126625121945 test accuracy=0.2240981126065143
# Elapsed time: 13.9175 seconds
# feature 9 : gene 8966  280 samples
# training error=2.382443705576682 test error=1.958111013777176
# training accuracy=0.2504429888307086 test accuracy=0.24329059488731386
# Elapsed time: 13.9150 seconds
# feature 10 : gene 7409  300 samples
# training error=2.144085850239911 test error=2.0381460539937883
# training accuracy=0.249805881298903 test accuracy=0.24305168431950305
# Elapsed time: 13.8274 seconds
# feature 11 : gene 7261  320 samples
# training error=2.72568538833695 test error=2.3623476945130206
# training accuracy=0.2543651820733868 test accuracy=0.24870590109102492
# Elapsed time: 13.9892 seconds
# feature 12 : gene 25992  340 samples
# training error=2.557608457602485 test error=2.499721271004221
# training accuracy=0.26216974933800546 test accuracy=0.25913832921876245
# Elapsed time: 14.0175 seconds
# feature 13 : gene 9902  360 samples
# training error=3.6344595536265354 test error=4.445807119534921
# training accuracy=0.27116889322475957 test accuracy=0.2685354782193199
# Elapsed time: 14.4497 seconds
# feature 14 : gene 13748  380 samples
# training error=3.991737511696896 test error=4.83228478139683
# training accuracy=0.2733191311446035 test accuracy=0.26781874651588755
# Elapsed time: 14.7613 seconds
# feature 15 : gene 26104  400 samples
# training error=3.925259322675055 test error=4.857529664728837
# training accuracy=0.2755091882851853 test accuracy=0.26781874651588755
# Elapsed time: 14.5949 seconds
# feature 16 : gene 18493  419 samples
# training error=4.461206124196149 test error=5.335828621486024
# training accuracy=0.2918350687877038 test accuracy=0.28653340766106555
# Elapsed time: 15.1480 seconds
# feature 17 : gene 20485  439 samples
# training error=5.6074621219662735 test error=6.18714661145178
# training accuracy=0.3045174905927091 test accuracy=0.2993549414669109
# Elapsed time: 14.8313 seconds
# feature 18 : gene 3045  459 samples
# training error=5.436179743962411 test error=5.599904435772876
# training accuracy=0.31628407032074385 test accuracy=0.312415385840567
# Elapsed time: 14.9793 seconds
# feature 19 : gene 25718  478 samples
# training error=5.601728154180023 test error=6.066894958987019
# training accuracy=0.33071853783821453 test accuracy=0.32690929362108784
# Elapsed time: 15.1444 seconds
# feature 20 : gene 17562  497 samples
# training error=5.814362792920143 test error=6.975471848371426
# training accuracy=0.3395982240627551 test accuracy=0.33702317432507767
# Elapsed time: 15.0332 seconds
# feature 21 : gene 4325  517 samples
# training error=6.105122742747924 test error=6.895118260731066
# training accuracy=0.34465526509646205 test accuracy=0.3404475591303655
# Elapsed time: 15.3697 seconds
# feature 22 : gene 25038  537 samples
# training error=6.350389232882712 test error=7.499641634148284
# training accuracy=0.3504290521034503 test accuracy=0.3475352393087521
# Elapsed time: 15.2214 seconds
# feature 23 : gene 5776  557 samples
# training error=6.302586258386923 test error=7.316158318069602
# training accuracy=0.3564019352141279 test accuracy=0.35470255634307557
# Elapsed time: 15.6572 seconds
# feature 24 : gene 24025  577 samples
# training error=6.52232862802875 test error=7.310822648721828
# training accuracy=0.3615784339100484 test accuracy=0.357569483156805
# Elapsed time: 15.3724 seconds
# feature 25 : gene 17585  596 samples
# training error=6.237023911442053 test error=7.234610177590189
# training accuracy=0.36544089832161986 test accuracy=0.3607549573942821
# Elapsed time: 15.8948 seconds
# feature 26 : gene 9890  615 samples
# training error=6.291775339956597 test error=7.573942820737437
# training accuracy=0.370975770004181 test accuracy=0.36394043163175915
# Elapsed time: 16.1066 seconds
# feature 27 : gene 15472  634 samples
# training error=6.497302247795011 test error=7.616867086087441
# training accuracy=0.38156768272044916 test accuracy=0.3772397865732261
# Elapsed time: 16.0795 seconds
# feature 28 : gene 11641  654 samples
# training error=6.656081390487188 test error=7.711316397228638
# training accuracy=0.38425548012025407 test accuracy=0.3813012662260094
# Elapsed time: 16.0891 seconds
# feature 29 : gene 2785  674 samples
# training error=6.803432416827603 test error=7.804093334395158
# training accuracy=0.38853604634957295 test accuracy=0.38576093015847734
# Elapsed time: 18.1387 seconds
# feature 30 : gene 13486  692 samples
# training error=6.606844924044837 test error=7.551485227363224
# training accuracy=0.39106456686642643 test accuracy=0.38950386238751294
# Elapsed time: 16.9351 seconds
# feature 31 : gene 9410  711 samples
# training error=7.046907042029187 test error=7.610097953332803
# training accuracy=0.3957234156927549 test accuracy=0.3934060683284224
# Elapsed time: 16.4454 seconds
# feature 32 : gene 9333  731 samples
# training error=6.891393075437514 test error=7.671259058692363
# training accuracy=0.4019949429589663 test accuracy=0.39882137453213345
# Elapsed time: 18.2696 seconds
# feature 33 : gene 1142  751 samples
# training error=6.893981324785474 test error=7.485944094927132
# training accuracy=0.40812710295259524 test accuracy=0.40256430676116906
# Elapsed time: 18.2366 seconds
# feature 34 : gene 7570  771 samples
# training error=6.947816911223048 test error=7.315361949510233
# training accuracy=0.40997869671690523 test accuracy=0.4058294178545831
# Elapsed time: 18.5701 seconds
# feature 35 : gene 23228  791 samples
# training error=6.990722121568081 test error=7.644262164529744
# training accuracy=0.4162900432038545 test accuracy=0.40941307637174484
# Elapsed time: 18.5713 seconds
# feature 36 : gene 15153  811 samples
# training error=6.907778684771139 test error=7.325316556502349
# training accuracy=0.419614948135465 test accuracy=0.41315600860078044
# Elapsed time: 18.7346 seconds
# feature 37 : gene 15411  831 samples
# training error=7.007983753757939 test error=7.316875049773035
# training accuracy=0.41959503852509605 test accuracy=0.4129967348889066
# Elapsed time: 19.2023 seconds
# feature 38 : gene 25934  850 samples
# training error=6.835108606924562 test error=7.053038146053994
# training accuracy=0.4236565990403568 test accuracy=0.41658039340606834
# Elapsed time: 19.1733 seconds
# feature 39 : gene 18040  870 samples
# training error=6.764847591932626 test error=7.015688460619574
# training accuracy=0.425727198518725 test accuracy=0.4188898622282392
# Elapsed time: 19.0605 seconds
# feature 40 : gene 4094  889 samples
# training error=6.667489597228582 test error=6.978099864617345
# training accuracy=0.42797698449041355 test accuracy=0.4205622362029147
# Elapsed time: 19.5432 seconds
# feature 41 : gene 16018  907 samples
# training error=6.667131224241942 test error=6.887632396272995
# training accuracy=0.42825571903557846 test accuracy=0.4229513418810225
# Elapsed time: 19.2137 seconds
# feature 42 : gene 9676  926 samples
# training error=6.576701773946284 test error=6.439675081627778
# training accuracy=0.4340892348736735 test accuracy=0.4282073743728598
# Elapsed time: 19.6262 seconds
# feature 43 : gene 19949  946 samples
# training error=6.405280028669839 test error=6.263199808871546
# training accuracy=0.4378123320126625 test accuracy=0.4314724854662738
# Elapsed time: 20.3986 seconds
# feature 44 : gene 4780  966 samples
# training error=6.224580404961475 test error=6.1737676196543765
# training accuracy=0.4416947060346029 test accuracy=0.4357728756868679
# Elapsed time: 20.0231 seconds
# feature 45 : gene 1731  986 samples
# training error=5.93423855695144 test error=6.240503304929521
# training accuracy=0.44511915901805804 test accuracy=0.43863980250059725
# Elapsed time: 20.2959 seconds
# feature 46 : gene 11149  1004 samples
# training error=5.798773568001274 test error=6.0984311539380425
# training accuracy=0.448842256157047 test accuracy=0.4441347455602453
# Elapsed time: 20.3168 seconds
# feature 47 : gene 1666  1024 samples
# training error=5.803750970593505 test error=6.186190969180537
# training accuracy=0.4500169231688136 test accuracy=0.44461256669586685
# Elapsed time: 20.8866 seconds
# feature 48 : gene 17391  1044 samples
# training error=5.798574471897585 test error=6.261447798040933
# training accuracy=0.451768968881279 test accuracy=0.4460460301027315
# Elapsed time: 20.6087 seconds
# feature 49 : gene 7669  1062 samples
# training error=5.722181296912019 test error=6.336863900613204
# training accuracy=0.45427757978776356 test accuracy=0.4500278728995779
# Elapsed time: 20.7254 seconds
# feature 50 : gene 12155  1081 samples
# training error=5.786210603858483 test error=6.33877518515569
# training accuracy=0.45760248471937404 test accuracy=0.4534522577048658
# Elapsed time: 18.7226 seconds
# feature 51 : gene 18728  1100 samples
# training error=5.659366476198061 test error=6.403042127896791
# training accuracy=0.4607482031576642 test accuracy=0.4560006370948475
# Elapsed time: 21.2390 seconds
# feature 52 : gene 3642  1119 samples
# training error=5.669400919823999 test error=6.3199012502986385
# training accuracy=0.4683138550978557 test accuracy=0.46253085928167553
# Elapsed time: 20.9435 seconds
# feature 53 : gene 1353  1138 samples
# training error=5.683437195134092 test error=6.196065939316716
# training accuracy=0.47014553925179686 test accuracy=0.4649199649597834
# Elapsed time: 21.7373 seconds
# feature 54 : gene 21309  1156 samples
# training error=5.979493101320007 test error=6.515170821055984
# training accuracy=0.4738487267804169 test accuracy=0.46858326033288206
# Elapsed time: 19.7458 seconds
# feature 55 : gene 5595  1176 samples
# training error=5.943894717980369 test error=6.4493907780520825
# training accuracy=0.47520258028550383 test accuracy=0.4693796288922513
# Elapsed time: 21.5156 seconds
# feature 56 : gene 17355  1195 samples
# training error=5.990204471698489 test error=6.5109500676913274
# training accuracy=0.47492384574033886 test accuracy=0.46890180775662976
# Elapsed time: 19.4005 seconds
# feature 57 : gene 14057  1213 samples
# training error=6.06076413084596 test error=6.7340129011706615
# training accuracy=0.47619806080395005 test accuracy=0.4701759974516206
# Elapsed time: 19.6543 seconds
# feature 58 : gene 12800  1233 samples
# training error=5.970613415095467 test error=6.637174484351358
# training accuracy=0.47910486391781315 test accuracy=0.4739985665365931
# Elapsed time: 19.8612 seconds
# feature 59 : gene 12260  1253 samples
# training error=6.154020745814004 test error=6.576809747551167
# training accuracy=0.48314651482270493 test accuracy=0.4780600461893764
# Elapsed time: 21.9524 seconds
# feature 60 : gene 13053  1273 samples
# training error=6.147589941664841 test error=6.817551963048499
# training accuracy=0.48557548728771377 test accuracy=0.4786971410368719
# Elapsed time: 20.1031 seconds
# feature 61 : gene 6440  1292 samples
# training error=5.6981703068070955 test error=6.397387911125269
# training accuracy=0.4918669241642941 test accuracy=0.4874571951899339
# Elapsed time: 20.2164 seconds
# feature 62 : gene 17035  1311 samples
# training error=5.664323969179923 test error=6.293859998407263
# training accuracy=0.4920062914368766 test accuracy=0.4889702954527355
# Elapsed time: 20.4371 seconds
# feature 63 : gene 7694  1330 samples
# training error=5.544746849304159 test error=6.0675320538345145
# training accuracy=0.49594839428992377 test accuracy=0.4904833957155372
# Elapsed time: 20.7832 seconds
# feature 64 : gene 6852  1350 samples
# training error=5.5712664503155676 test error=5.898861192960102
# training accuracy=0.49770044000238917 test accuracy=0.4942263279445728
# Elapsed time: 20.2011 seconds
# feature 65 : gene 18101  1370 samples
# training error=5.513309574531626 test error=5.803934060683284
# training accuracy=0.49899456467636927 test accuracy=0.4952616070717528
# Elapsed time: 20.2366 seconds
# feature 66 : gene 12882  1388 samples
# training error=5.680052561371374 test error=5.941546547742295
# training accuracy=0.5006470623369901 test accuracy=0.49749143903798676
# Elapsed time: 21.1945 seconds
# feature 67 : gene 17290  1406 samples
# training error=5.692695163955642 test error=5.891375328502031
# training accuracy=0.5023393792183487 test accuracy=0.4986859918770407
# Elapsed time: 20.5592 seconds
# feature 68 : gene 25957  1425 samples
# training error=5.692376610189738 test error=6.069841522656685
# training accuracy=0.5030163059708922 test accuracy=0.5004380027076532
# Elapsed time: 21.2975 seconds
# feature 69 : gene 22545  1445 samples
# training error=5.617994305851434 test error=5.722943378195429
# training accuracy=0.5040117864893384 test accuracy=0.5029067452416979
# Elapsed time: 22.0644 seconds
# feature 70 : gene 22489  1463 samples
# training error=5.511278794273996 test error=5.766902922672613
# training accuracy=0.5065004877854541 test accuracy=0.5067293143266703
# Elapsed time: 21.7393 seconds
# feature 71 : gene 1699  1483 samples
# training error=5.564576821231609 test error=5.799792944174564
# training accuracy=0.5090688275230454 test accuracy=0.5073664091741658
# Elapsed time: 22.1980 seconds
# feature 72 : gene 25954  1503 samples
# training error=5.597567045612918 test error=5.6668790316158315
# training accuracy=0.5112588846636271 test accuracy=0.5096758779963367
# Elapsed time: 23.6359 seconds
# feature 73 : gene 5217  1522 samples
# training error=5.561092639417047 test error=5.598152424942263
# training accuracy=0.5139068628426942 test accuracy=0.5119057099625707
# Elapsed time: 21.9554 seconds
# feature 74 : gene 19194  1542 samples
# training error=5.5236625719234675 test error=5.731942342916302
# training accuracy=0.5181476098512752 test accuracy=0.5141355419288046
# Elapsed time: 22.5154 seconds
# feature 75 : gene 18640  1561 samples
# training error=5.497580982340176 test error=5.666719757903958
# training accuracy=0.5185657116690227 test accuracy=0.51373735764912
# Elapsed time: 22.4265 seconds
# feature 76 : gene 557  1581 samples
# training error=5.519043542317877 test error=5.755594489129569
# training accuracy=0.5203774862125948 test accuracy=0.5144540893525523
# Elapsed time: 23.1626 seconds
# feature 77 : gene 11336  1600 samples
# training error=5.43211818344715 test error=5.635900294656367
# training accuracy=0.5223684472494873 test accuracy=0.5158875527594171
# Elapsed time: 25.4090 seconds
# feature 78 : gene 20459  1619 samples
# training error=5.473450534573038 test error=5.645775264792546
# training accuracy=0.5237023911442054 test accuracy=0.519232300708768
# Elapsed time: 24.0899 seconds
# feature 79 : gene 1393  1638 samples
# training error=5.409003125808828 test error=5.554113243609143
# training accuracy=0.5251358830907679 test accuracy=0.5197897587003265
# Elapsed time: 23.7385 seconds
# feature 80 : gene 20057  1658 samples
# training error=5.493021681565692 test error=5.632236999283268
# training accuracy=0.5283811495809027 test accuracy=0.5249661543362268
# Elapsed time: 23.7995 seconds
# feature 81 : gene 13040  1676 samples
# training error=5.357457144563681 test error=5.746038066417138
# training accuracy=0.5304915682800088 test accuracy=0.5274348968702716
# Elapsed time: 24.4581 seconds
# feature 82 : gene 5902  1696 samples
# training error=5.491209907022119 test error=5.547503384566378
# training accuracy=0.5303123817866884 test accuracy=0.5283905391415147
# Elapsed time: 23.8851 seconds
# feature 83 : gene 17166  1714 samples
# training error=5.43860871642742 test error=5.658994982878076
# training accuracy=0.5319449698369403 test accuracy=0.5294258182686947
# Elapsed time: 27.1393 seconds
# feature 84 : gene 13611  1734 samples
# training error=5.3517032671670615 test error=5.877279605001195
# training accuracy=0.5340354789256774 test accuracy=0.5299832762602532
# Elapsed time: 25.3656 seconds
# feature 85 : gene 5591  1753 samples
# training error=5.375913353375674 test error=5.801146770725492
# training accuracy=0.5348318633404344 test accuracy=0.5309389185314963
# Elapsed time: 25.2427 seconds
# feature 86 : gene 9852  1771 samples
# training error=5.3633902084536205 test error=5.938122162937007
# training accuracy=0.5357676150277739 test accuracy=0.532452018794298
# Elapsed time: 25.0705 seconds
# feature 87 : gene 12904  1790 samples
# training error=5.197105142652358 test error=5.8212152584215975
# training accuracy=0.5391721584008601 test accuracy=0.5361949510233336
# Elapsed time: 27.2760 seconds
# feature 88 : gene 26345  1808 samples
# training error=5.107173432615924 test error=5.757983594807677
# training accuracy=0.5417604077488204 test accuracy=0.5375487775742613
# Elapsed time: 25.3366 seconds
# feature 89 : gene 23590  1826 samples
# training error=5.133832400899914 test error=5.800191128454249
# training accuracy=0.5435124534612857 test accuracy=0.5394600621167477
# Elapsed time: 26.2531 seconds
# feature 90 : gene 11266  1845 samples
# training error=5.16522985645171 test error=5.871227203949988
# training accuracy=0.5455830529396539 test accuracy=0.540256430676117
# Elapsed time: 25.6469 seconds
# feature 91 : gene 5931  1865 samples
# training error=5.164533020088797 test error=6.000477821135622
# training accuracy=0.5462798893025663 test accuracy=0.5399378832523692
# Elapsed time: 26.6419 seconds
# feature 92 : gene 17550  1885 samples
# training error=5.156549266330858 test error=5.9176554909612165
# training accuracy=0.5470762737173234 test accuracy=0.5409731623795493
# Elapsed time: 26.7890 seconds
# feature 93 : gene 2833  1905 samples
# training error=5.110737252871961 test error=5.839053914151469
# training accuracy=0.5486690425468373 test accuracy=0.5430437206339094
# Elapsed time: 27.6286 seconds
# feature 94 : gene 9719  1922 samples
# training error=5.014832659724849 test error=5.721350641076691
# training accuracy=0.5494455173512255 test accuracy=0.5440789997610894
# Elapsed time: 28.2547 seconds
# feature 95 : gene 2142  1941 samples
# training error=4.878850020905091 test error=5.609859042764992
# training accuracy=0.5527903318932048 test accuracy=0.5450346420323325
# Elapsed time: 27.9001 seconds
# feature 96 : gene 6685  1960 samples
# training error=4.876679873374878 test error=5.58397706458549
# training accuracy=0.5542835526708743 test accuracy=0.5459106474476387
# Elapsed time: 28.0721 seconds
# feature 97 : gene 10248  1980 samples
# training error=4.814243335257929 test error=5.4361710599665525
# training accuracy=0.5555975869552233 test accuracy=0.5482201162698097
# Elapsed time: 27.9361 seconds
# feature 98 : gene 6482  2000 samples
# training error=4.658809007107731 test error=5.340925380265987
# training accuracy=0.5569713500706791 test accuracy=0.5499721271004221
# Elapsed time: 29.7046 seconds
# feature 99 : gene 20984  2019 samples
# training error=4.598084695482509 test error=5.269252209922752
# training accuracy=0.5578871921476497 test accuracy=0.5507684956597914
# Elapsed time: 28.1395 seconds
# feature 100 : gene 8756  2037 samples
# training error=4.652378202958568 test error=5.266942741100581
# training accuracy=0.5594003225356879 test accuracy=0.5518834116429083
# Elapsed time: 28.4922 seconds
# feature 101 : gene 13331  2056 samples
# training error=4.679992832540267 test error=5.2525284701759976
# training accuracy=0.5606148087681924 test accuracy=0.5529983276260253
# Elapsed time: 29.4104 seconds
# feature 102 : gene 9672  2075 samples
# training error=4.649132936468433 test error=5.308592816755595
# training accuracy=0.5615505604555319 test accuracy=0.5549096121685115
# Elapsed time: 28.9156 seconds
# feature 103 : gene 473  2095 samples
# training error=4.709339598224063 test error=5.298558572907542
# training accuracy=0.5624664025325025 test accuracy=0.5561041650075655
# Elapsed time: 29.0461 seconds
# feature 104 : gene 5660  2114 samples
# training error=4.635813407131622 test error=5.397467547981206
# training accuracy=0.5633424253887351 test accuracy=0.5583339969737995
# Elapsed time: 30.0329 seconds
# feature 105 : gene 12109  2132 samples
# training error=4.662810838791885 test error=5.423508799872581
# training accuracy=0.5646763692834531 test accuracy=0.5576172652703671
# Elapsed time: 29.4313 seconds
# feature 106 : gene 4464  2150 samples
# training error=4.637047802974496 test error=5.366807358445489
# training accuracy=0.5663288669440739 test accuracy=0.5589710918212949
# Elapsed time: 29.4295 seconds
# feature 107 : gene 4377  2169 samples
# training error=4.702928703685269 test error=5.542725173210162
# training accuracy=0.5666076014892388 test accuracy=0.5592896392450426
# Elapsed time: 30.1709 seconds
# feature 108 : gene 14731  2189 samples
# training error=4.731857367551317 test error=5.466751612646333
# training accuracy=0.5672247994106755 test accuracy=0.5618380186350243
# Elapsed time: 30.8340 seconds
# feature 109 : gene 4024  2208 samples
# training error=4.6993847930396 test error=5.574420641873059
# training accuracy=0.5687180201883449 test accuracy=0.5636696663215737
# Elapsed time: 30.6119 seconds
# feature 110 : gene 23190  2226 samples
# training error=4.720926991458777 test error=5.370550290674524
# training accuracy=0.5684591952535489 test accuracy=0.5646253085928168
# Elapsed time: 31.9038 seconds
# feature 111 : gene 18021  2245 samples
# training error=4.671571067354212 test error=5.418412041092617
# training accuracy=0.5703107890178589 test accuracy=0.5662180457115553
# Elapsed time: 30.5074 seconds
# feature 112 : gene 8731  2265 samples
# training error=4.620204272602385 test error=5.405112686151151
# training accuracy=0.5709877157704024 test accuracy=0.5679700565421677
# Elapsed time: 30.6502 seconds
# feature 113 : gene 8218  2284 samples
# training error=4.661357437234953 test error=5.429800111491598
# training accuracy=0.5711270830429849 test accuracy=0.5692442462371585
# Elapsed time: 30.4883 seconds
# feature 114 : gene 15244  2302 samples
# training error=4.525115973480399 test error=5.166918850043801
# training accuracy=0.5747108129093914 test accuracy=0.5701998885084016
# Elapsed time: 32.1545 seconds
# feature 115 : gene 25810  2321 samples
# training error=4.560973181754833 test error=5.171537787688142
# training accuracy=0.5745515360264399 test accuracy=0.5718722624830772
# Elapsed time: 31.4889 seconds
# feature 116 : gene 2789  2340 samples
# training error=4.549704342286021 test error=5.15346022139046
# training accuracy=0.5745515360264399 test accuracy=0.5723500836186988
# Elapsed time: 31.7877 seconds
# feature 117 : gene 21710  2358 samples
# training error=4.546140522029984 test error=5.043003902205941
# training accuracy=0.5758854799211579 test accuracy=0.5739428207374373
# Elapsed time: 31.7254 seconds
# feature 118 : gene 19642  2377 samples
# training error=4.607044020148526 test error=5.046428287011229
# training accuracy=0.5764230394011189 test accuracy=0.5744206418730589
# Elapsed time: 31.7444 seconds
# feature 119 : gene 8221  2395 samples
# training error=4.579708125111992 test error=5.111491598311699
# training accuracy=0.5773986103091963 test accuracy=0.5762522895596082
# Elapsed time: 32.3942 seconds
# feature 120 : gene 4789  2414 samples
# training error=4.539152248790491 test error=5.271243131321175
# training accuracy=0.5792701136838752 test accuracy=0.5761726527036712
# Elapsed time: 32.9601 seconds
# feature 121 : gene 8715  2432 samples
# training error=4.4876062675453445 test error=5.158079159034801
# training accuracy=0.579847492384574 test accuracy=0.5763319264155451
# Elapsed time: 33.0361 seconds
# feature 122 : gene 13724  2452 samples
# training error=4.463097537181198 test error=5.2054630883172734
# training accuracy=0.5810022497859717 test accuracy=0.577526479254599
# Elapsed time: 32.4375 seconds
# feature 123 : gene 26364  2470 samples
# training error=4.420411332550222 test error=5.175201083061241
# training accuracy=0.58251538017401 test accuracy=0.5778450266783467
# Elapsed time: 32.8882 seconds
# feature 124 : gene 21191  2488 samples
# training error=4.445298345511378 test error=5.193756470494545
# training accuracy=0.5826348378362235 test accuracy=0.5780839372461575
# Elapsed time: 33.2809 seconds
# feature 125 : gene 7046  2507 samples
# training error=4.362773010532184 test error=5.104483554989249
# training accuracy=0.5838891432894658 test accuracy=0.5790395795174007
# Elapsed time: 33.5376 seconds
# feature 126 : gene 18019  2526 samples
# training error=4.374161307663209 test error=5.102014812455204
# training accuracy=0.5842873354968443 test accuracy=0.5792784900852115
# Elapsed time: 33.6599 seconds
# feature 127 : gene 2826  2546 samples
# training error=4.299759093714536 test error=5.190411722545194
# training accuracy=0.5850638103012324 test accuracy=0.57983594807677
# Elapsed time: 34.8192 seconds
# feature 128 : gene 18561  2566 samples
# training error=4.332171939395146 test error=5.23381380903082
# training accuracy=0.5862384773129989 test accuracy=0.5806323166361392
# Elapsed time: 34.2989 seconds
# feature 129 : gene 24763  2584 samples
# training error=4.318653313954646 test error=5.190570996257068
# training accuracy=0.5882891671809982 test accuracy=0.581986143187067
# Elapsed time: 34.4758 seconds
# feature 130 : gene 9494  2602 samples
# training error=4.332948414199534 test error=5.181253484112447
# training accuracy=0.5891054612061242 test accuracy=0.5826232380345624
# Elapsed time: 34.7293 seconds
# feature 131 : gene 20035  2621 samples
# training error=4.34190773886555 test error=4.965835788803058
# training accuracy=0.5893642861409202 test accuracy=0.5850123437126702
# Elapsed time: 33.6993 seconds
# feature 132 : gene 15821  2640 samples
# training error=4.415473749178728 test error=5.03575694831568
# training accuracy=0.5899217552312501 test accuracy=0.5850919805686071
# Elapsed time: 35.0860 seconds
# feature 133 : gene 6964  2658 samples
# training error=4.4186194676170185 test error=5.0487377558333995
# training accuracy=0.5901606705556772 test accuracy=0.5858087122720395
# Elapsed time: 34.3268 seconds
# feature 134 : gene 15073  2676 samples
# training error=4.324924841220858 test error=4.988611929601019
# training accuracy=0.5914348856192885 test accuracy=0.5864458071195349
# Elapsed time: 35.1576 seconds
# feature 135 : gene 15391  2693 samples
# training error=4.245326218965895 test error=4.931751214462053
# training accuracy=0.592629462241424 test accuracy=0.587560723102652
# Elapsed time: 34.1796 seconds
# feature 136 : gene 11352  2712 samples
# training error=4.260576980508492 test error=5.0294656366966635
# training accuracy=0.5940629541879865 test accuracy=0.5880385442382735
# Elapsed time: 35.8408 seconds
# feature 137 : gene 22222  2729 samples
# training error=4.213012921337129 test error=4.992514135541929
# training accuracy=0.5957552710693452 test accuracy=0.5900294656366967
# Elapsed time: 35.5097 seconds
# feature 138 : gene 793  2748 samples
# training error=4.2130328309474985 test error=4.997371983754081
# training accuracy=0.5960340056145101 test accuracy=0.5899498287807597
# Elapsed time: 35.1380 seconds
# feature 139 : gene 22931  2768 samples
# training error=4.212555000298644 test error=4.925141355419288
# training accuracy=0.5960937344456169 test accuracy=0.5901091024926336
# Elapsed time: 36.8602 seconds
# feature 140 : gene 19495  2786 samples
# training error=4.260676528560336 test error=5.017201560882376
# training accuracy=0.5969498476914806 test accuracy=0.5909054710520029
# Elapsed time: 36.3732 seconds
# feature 141 : gene 3444  2802 samples
# training error=4.248730762338981 test error=4.9422632794457275
# training accuracy=0.5973679495092281 test accuracy=0.5916222027554352
# Elapsed time: 36.0984 seconds
# feature 142 : gene 26556  2822 samples
# training error=4.210802954586179 test error=4.955005176395636
# training accuracy=0.5980249666514026 test accuracy=0.5920203870351198
# Elapsed time: 35.9013 seconds
# feature 143 : gene 22412  2840 samples
# training error=4.216935114579807 test error=4.808951182607311
# training accuracy=0.5989408087283732 test accuracy=0.592896392450426
# Elapsed time: 35.8989 seconds
# feature 144 : gene 16226  2858 samples
# training error=4.218826527564856 test error=4.777813171935972
# training accuracy=0.5996575547016545 test accuracy=0.5937723978657322
# Elapsed time: 36.8212 seconds
# feature 145 : gene 17365  2878 samples
# training error=4.1580225774981585 test error=4.900613203790714
# training accuracy=0.5999960180779262 test accuracy=0.5941705821454168
# Elapsed time: 36.9159 seconds
# feature 146 : gene 2798  2894 samples
# training error=4.155474147370936 test error=4.782432109580314
# training accuracy=0.6006530352201007 test accuracy=0.5948873138488493
# Elapsed time: 37.4052 seconds
# feature 147 : gene 25089  2909 samples
# training error=4.156429808668644 test error=4.83332006052401
# training accuracy=0.6009715889860036 test accuracy=0.5950465875607232
# Elapsed time: 35.8082 seconds
# feature 148 : gene 23082  2926 samples
# training error=4.104684731319808 test error=4.833399697379948
# training accuracy=0.60140960041412 test accuracy=0.5960022298319663
# Elapsed time: 36.6934 seconds
# feature 149 : gene 19213  2942 samples
# training error=4.077766938101021 test error=4.899896472087282
# training accuracy=0.6019471598940809 test accuracy=0.5956836824082186
# Elapsed time: 37.6763 seconds
# feature 150 : gene 25499  2961 samples
# training error=4.03482190853525 test error=4.866847176873457
# training accuracy=0.6031019172954786 test accuracy=0.597435693238831
# Elapsed time: 37.7594 seconds
# feature 151 : gene 17779  2979 samples
# training error=4.128635992593625 test error=4.670144142709246
# training accuracy=0.6037390248272841 test accuracy=0.5982320617982002
# Elapsed time: 37.7210 seconds
# feature 152 : gene 3638  2997 samples
# training error=4.105102833137556 test error=4.5458310105917015
# training accuracy=0.6042367650865073 test accuracy=0.5987098829338218
# Elapsed time: 37.9753 seconds
# feature 153 : gene 16946  3016 samples
# training error=4.107531805602564 test error=4.6335908258341965
# training accuracy=0.6059290819678659 test accuracy=0.5993469777813172
# Elapsed time: 38.4158 seconds
# feature 154 : gene 24896  3031 samples
# training error=4.0799171760208655 test error=4.514533726208489
# training accuracy=0.6065860991100405 test accuracy=0.6012582623238034
# Elapsed time: 39.1361 seconds
# feature 155 : gene 6088  3050 samples
# training error=4.068190415513568 test error=4.532213108226487
# training accuracy=0.6073824835247974 test accuracy=0.601736083459425
# Elapsed time: 37.5082 seconds
# feature 156 : gene 167  3069 samples
# training error=4.032253568797659 test error=4.51660428446285
# training accuracy=0.6085770601469329 test accuracy=0.6033288205781636
# Elapsed time: 38.5212 seconds
# feature 157 : gene 4684  3088 samples
# training error=3.9600015927688297 test error=4.56040455522816
# training accuracy=0.6092539868994764 test accuracy=0.6038066417137852
# Elapsed time: 38.7745 seconds
# feature 158 : gene 8869  3106 samples
# training error=3.927469289426006 test error=4.526001433463406
# training accuracy=0.6091345292372629 test accuracy=0.6035677311459744
# Elapsed time: 38.5693 seconds
# feature 159 : gene 17510  3124 samples
# training error=3.931132657733888 test error=4.351517082105598
# training accuracy=0.6099707328727577 test accuracy=0.6060364736800191
# Elapsed time: 38.6088 seconds
# feature 160 : gene 18459  3141 samples
# training error=3.867640910267386 test error=4.3457832284781395
# training accuracy=0.6111055806637864 test accuracy=0.6065142948156407
# Elapsed time: 38.4058 seconds
# feature 161 : gene 3915  3159 samples
# training error=3.8853604634957293 test error=4.319423429163017
# training accuracy=0.6120015131303881 test accuracy=0.6073106633750099
# Elapsed time: 39.4468 seconds
# feature 162 : gene 2004  3178 samples
# training error=3.929340792800685 test error=4.365931353030183
# training accuracy=0.6129173552073586 test accuracy=0.6075495739428207
# Elapsed time: 39.0671 seconds
# feature 163 : gene 3619  3196 samples
# training error=3.9112628665857008 test error=4.403042127896791
# training accuracy=0.6135146435184263 test accuracy=0.6077884845106315
# Elapsed time: 39.1221 seconds
# feature 164 : gene 9907  3214 samples
# training error=3.9191072530710573 test error=4.560962013219718
# training accuracy=0.6142114798813387 test accuracy=0.6073903002309469
# Elapsed time: 39.7310 seconds
# feature 165 : gene 11036  3232 samples
# training error=3.919186891512533 test error=4.493350322529267
# training accuracy=0.6143110279331834 test accuracy=0.6085052162140638
# Elapsed time: 99.1851 seconds
# feature 166 : gene 12530  3250 samples
# training error=3.923487367352221 test error=4.437126702237796
# training accuracy=0.6147490393612997 test accuracy=0.6085848530700008
# Elapsed time: 39.6577 seconds
# feature 167 : gene 23320  3270 samples
# training error=3.944213271746272 test error=4.321493987417377
# training accuracy=0.6161626216974934 test accuracy=0.6089830373496854
# Elapsed time: 40.1798 seconds
# feature 168 : gene 16337  3290 samples
# training error=3.9199036374858145 test error=4.355976746038066
# training accuracy=0.6164413562426583 test accuracy=0.6097794059090547
# Elapsed time: 38.9609 seconds
# feature 169 : gene 18526  3306 samples
# training error=3.8792083938917314 test error=4.303097873695947
# training accuracy=0.6174766559818424 test accuracy=0.6126463327227841
# Elapsed time: 40.3865 seconds
# feature 170 : gene 11628  3326 samples
# training error=3.8871324188185636 test error=4.346977781317194
# training accuracy=0.6183526788380751 test accuracy=0.613920522417775
# Elapsed time: 39.8357 seconds
# feature 171 : gene 15593  3344 samples
# training error=3.854281561709837 test error=4.251095006769133
# training accuracy=0.6193282497461524 test accuracy=0.6142390698415227
# Elapsed time: 40.4219 seconds
# feature 172 : gene 21685  3363 samples
# training error=3.840026280685687 test error=4.324201640519233
# training accuracy=0.6195671650705795 test accuracy=0.6141594329855857
# Elapsed time: 40.2481 seconds
# feature 173 : gene 17250  3382 samples
# training error=3.8377167658828917 test error=4.218045711555308
# training accuracy=0.619985266888327 test accuracy=0.6151947121127658
# Elapsed time: 41.5830 seconds
# feature 174 : gene 13788  3401 samples
# training error=3.829912198618273 test error=4.163574102094449
# training accuracy=0.620801560913453 test accuracy=0.614955801544955
# Elapsed time: 40.1235 seconds
# feature 175 : gene 24262  3417 samples
# training error=3.8334361996535726 test error=4.234291630166441
# training accuracy=0.6211599339000936 test accuracy=0.6155928963924504
# Elapsed time: 42.2947 seconds
# feature 176 : gene 10543  3437 samples
# training error=3.8422362474366376 test error=4.211913673648164
# training accuracy=0.6217373126007925 test accuracy=0.6172652703671259
# Elapsed time: 41.6906 seconds
# feature 177 : gene 4289  3454 samples
# training error=3.813685866167599 test error=4.175280719917177
# training accuracy=0.6227128835088698 test accuracy=0.6176634546468105
# Elapsed time: 40.9837 seconds
# feature 178 : gene 5788  3471 samples
# training error=3.763234913492743 test error=4.112287966871068
# training accuracy=0.6227327931192387 test accuracy=0.6168670860874412
# Elapsed time: 41.3588 seconds
# feature 179 : gene 18093  3487 samples
# training error=3.7317777291098415 test error=4.219160627538424
# training accuracy=0.6234097198717821 test accuracy=0.6172652703671259
# Elapsed time: 41.2076 seconds
# feature 180 : gene 22425  3506 samples
# training error=3.6743584128058613 test error=4.1631759178147645
# training accuracy=0.6237680928584227 test accuracy=0.618300549494306
# Elapsed time: 41.7824 seconds
# feature 181 : gene 9557  3523 samples
# training error=3.694865311485854 test error=4.244246237158557
# training accuracy=0.6240269177932188 test accuracy=0.6177430915027474
# Elapsed time: 42.5563 seconds
# feature 182 : gene 4794  3542 samples
# training error=3.6828000876022857 test error=4.216452974436569
# training accuracy=0.6244251100005973 test accuracy=0.6183801863502429
# Elapsed time: 42.4856 seconds
# feature 183 : gene 8818  3559 samples
# training error=3.6575746112648577 test error=4.239706936370152
# training accuracy=0.625042307922034 test accuracy=0.6198932866130445
# Elapsed time: 42.0631 seconds
# feature 184 : gene 21184  3576 samples
# training error=3.6114042248193203 test error=4.312574659552441
# training accuracy=0.6260576980508491 test accuracy=0.62053038146054
# Elapsed time: 43.0986 seconds
# feature 185 : gene 18886  3593 samples
# training error=3.5893443765305513 test error=4.213187863343156
# training accuracy=0.6266549863619169 test accuracy=0.6202914708927292
# Elapsed time: 108.1706 seconds
# feature 186 : gene 7695  3609 samples
# training error=3.5565532482529316 test error=4.245600063709484
# training accuracy=0.6268142632448683 test accuracy=0.6210878394520984
# Elapsed time: 42.6148 seconds
# feature 187 : gene 20730  3627 samples
# training error=3.534672586457483 test error=4.184757505773672
# training accuracy=0.6282278455810619 test accuracy=0.623795492553954
# Elapsed time: 42.7300 seconds
# feature 188 : gene 11807  3646 samples
# training error=3.5587233957831446 test error=4.214541689894083
# training accuracy=0.628247755191431 test accuracy=0.6246714979692601
# Elapsed time: 42.1238 seconds
# feature 189 : gene 15237  3662 samples
# training error=3.5561749656559223 test error=4.122242573863184
# training accuracy=0.6290640492165568 test accuracy=0.6234769451302062
# Elapsed time: 43.1030 seconds
# feature 190 : gene 1272  3677 samples
# training error=3.5890258227646483 test error=4.008680417297125
# training accuracy=0.6288450435024987 test accuracy=0.6240344031217647
# Elapsed time: 43.7059 seconds
# feature 191 : gene 1600  3696 samples
# training error=3.680729488123917 test error=4.002389105678108
# training accuracy=0.63085591414976 test accuracy=0.6250696822489448
# Elapsed time: 43.4640 seconds
# feature 192 : gene 10484  3711 samples
# training error=3.6716706154060565 test error=4.067850601258263
# training accuracy=0.6310948294741872 test accuracy=0.6244325874014494
# Elapsed time: 43.5782 seconds
# feature 193 : gene 15948  3729 samples
# training error=3.676289645011647 test error=4.0793979453691165
# training accuracy=0.6309554622016047 test accuracy=0.6257067770964402
# Elapsed time: 43.0937 seconds
# feature 194 : gene 11485  3745 samples
# training error=3.7150138371792063 test error=4.057895994266146
# training accuracy=0.6330459712903419 test accuracy=0.6266624193676834
# Elapsed time: 44.1306 seconds
# feature 195 : gene 5800  3765 samples
# training error=3.638600752583272 test error=4.076610655411324
# training accuracy=0.6339020845362057 test accuracy=0.627140240503305
# Elapsed time: 42.6060 seconds
# feature 196 : gene 18164  3782 samples
# training error=3.61307663209031 test error=4.0218204985267185
# training accuracy=0.6337428076532542 test accuracy=0.6291311619017281
# Elapsed time: 43.9696 seconds
# feature 197 : gene 11275  3799 samples
# training error=3.5775379775817786 test error=4.02150195110297
# training accuracy=0.634579011288749 test accuracy=0.6291311619017281
# Elapsed time: 43.9624 seconds
# feature 198 : gene 4070  3815 samples
# training error=3.622633245067394 test error=4.005574579915585
# training accuracy=0.634877655444283 test accuracy=0.6291311619017281
# Elapsed time: 44.6897 seconds
# feature 199 : gene 9752  3831 samples
# training error=3.6093336253409523 test error=3.9354941466910884
# training accuracy=0.635654130248671 test accuracy=0.6283347933423589
# Elapsed time: 44.1911 seconds
# feature 200 : gene 9763  3849 samples
# training error=3.617297469488522 test error=3.9364497889623316
# training accuracy=0.6362514185597388 test accuracy=0.6290515250457912
# Elapsed time: 110.9199 seconds
# feature 201 : gene 25298  3866 samples
# training error=3.6369084357019132 test error=4.0529585091980564
# training accuracy=0.6366496107671172 test accuracy=0.6295293461814128
# Elapsed time: 44.8451 seconds
# feature 202 : gene 18630  3885 samples
# training error=3.61233997650666 test error=4.0926176634546465
# training accuracy=0.6364306050530592 test accuracy=0.6306442621645297
# Elapsed time: 111.5430 seconds
# feature 203 : gene 3560  3900 samples
# training error=3.6602225894439244 test error=3.9732420164051923
# training accuracy=0.6373265375196607 test accuracy=0.6315202675798359
# Elapsed time: 44.9042 seconds
# feature 204 : gene 1287  3918 samples
# training error=3.603500109502857 test error=4.0014334634068645
# training accuracy=0.6377446393374082 test accuracy=0.6321573624273313
# Elapsed time: 45.4676 seconds
# feature 205 : gene 10657  3933 samples
# training error=3.5961733728870926 test error=3.954845902683762
# training accuracy=0.6382025603758934 test accuracy=0.6310424464442144
# Elapsed time: 111.2693 seconds
# feature 206 : gene 6968  3951 samples
# training error=3.600055746909033 test error=3.8873138488492476
# training accuracy=0.6385012045314273 test accuracy=0.6311220833001513
# Elapsed time: 44.8709 seconds
# feature 207 : gene 7145  3968 samples
# training error=3.6114042248193203 test error=3.9459265748188264
# training accuracy=0.6388396679076991 test accuracy=0.6312813570120251
# Elapsed time: 45.5580 seconds
# feature 208 : gene 17107  3986 samples
# training error=3.572899038365819 test error=3.9798518754479573
# training accuracy=0.6391980408943397 test accuracy=0.6327148204188898
# Elapsed time: 114.0313 seconds
# feature 209 : gene 9950  4001 samples
# training error=3.607482031576642 test error=4.102731544158637
# training accuracy=0.6410695442690186 test accuracy=0.6339890101138808
# Elapsed time: 44.9260 seconds
# feature 210 : gene 16180  4017 samples
# training error=3.581141617058554 test error=4.071832444055109
# training accuracy=0.6414876460867661 test accuracy=0.6340686469698177
# Elapsed time: 45.8805 seconds
# feature 211 : gene 19634  4034 samples
# training error=3.594680152109423 test error=4.086246714979692
# training accuracy=0.6416867421904553 test accuracy=0.634865015529187
# Elapsed time: 45.7762 seconds
# feature 212 : gene 5026  4050 samples
# training error=3.585462002508611 test error=4.091184200047782
# training accuracy=0.6418659286837757 test accuracy=0.6355817472326193
# Elapsed time: 44.8614 seconds
# feature 213 : gene 9613  4068 samples
# training error=3.5998765604157126 test error=4.10989886119296
# training accuracy=0.6423835785533677 test accuracy=0.636935573783547
# Elapsed time: 111.2048 seconds
# feature 214 : gene 12465  4085 samples
# training error=3.5686782009676072 test error=4.024687425340447
# training accuracy=0.6435383359547654 test accuracy=0.6386079477582225
# Elapsed time: 115.0452 seconds
# feature 215 : gene 1545  4104 samples
# training error=3.506540307006192 test error=4.015608823763638
# training accuracy=0.6443148107591534 test accuracy=0.6371744843513578
# Elapsed time: 45.5811 seconds
# feature 216 : gene 8949  4121 samples
# training error=3.5152408067374123 test error=3.998725810305009
# training accuracy=0.6444541780317359 test accuracy=0.636935573783547
# Elapsed time: 46.0926 seconds
# feature 217 : gene 9466  4140 samples
# training error=3.486053317936568 test error=4.017201560882376
# training accuracy=0.6449917375116969 test accuracy=0.636935573783547
# Elapsed time: 116.7560 seconds
# feature 218 : gene 3742  4155 samples
# training error=3.4524060764130846 test error=4.044835549892491
# training accuracy=0.6458677603679296 test accuracy=0.6365373895038624
# Elapsed time: 46.3369 seconds
# feature 219 : gene 22226  4174 samples
# training error=3.479403508073347 test error=4.0218204985267185
# training accuracy=0.6460867660819878 test accuracy=0.637015210639484
# Elapsed time: 46.0891 seconds
# feature 220 : gene 7626  4189 samples
# training error=3.5316065064606685 test error=4.085450346420323
# training accuracy=0.6459075795886674 test accuracy=0.6354224735207454
# Elapsed time: 46.9634 seconds
# feature 221 : gene 18017  4207 samples
# training error=3.52139287634141 test error=4.021581587958908
# training accuracy=0.6457881219264539 test accuracy=0.6355021103766824
# Elapsed time: 115.2671 seconds
# feature 222 : gene 21835  4222 samples
# training error=3.5724809365480716 test error=3.939237078920124
# training accuracy=0.6456885738746093 test accuracy=0.6366170263597993
# Elapsed time: 47.3627 seconds
# feature 223 : gene 19736  4238 samples
# training error=3.554124275787923 test error=4.011865891534602
# training accuracy=0.6460668564716189 test accuracy=0.6376523054869794
# Elapsed time: 110.8571 seconds
# feature 224 : gene 7205  4255 samples
# training error=3.5137674955701117 test error=3.9503862387512942
# training accuracy=0.646007127640512 test accuracy=0.6382097634785379
# Elapsed time: 46.9334 seconds
# feature 225 : gene 24532  4271 samples
# training error=3.500169231688136 test error=3.9165405749780997
# training accuracy=0.6464053198478906 test accuracy=0.6384486740463486
# Elapsed time: 109.0385 seconds
# feature 226 : gene 11267  4287 samples
# training error=3.5105819579110835 test error=4.01218443895835
# training accuracy=0.6463256814064149 test accuracy=0.6397228637413395
# Elapsed time: 115.7833 seconds
# feature 227 : gene 8493  4304 samples
# training error=3.485814402612141 test error=4.007485864458071
# training accuracy=0.6468831504967448 test accuracy=0.6393246794616548
# Elapsed time: 47.2403 seconds
# feature 228 : gene 4585  4322 samples
# training error=3.4418738925279233 test error=4.074062276021342
# training accuracy=0.647619806080395 test accuracy=0.6394839531735287
# Elapsed time: 112.5090 seconds
# feature 229 : gene 924  4341 samples
# training error=3.4297887590339857 test error=4.028828541849168
# training accuracy=0.6477989925737153 test accuracy=0.6397228637413395
# Elapsed time: 110.8325 seconds
# feature 230 : gene 22471  4357 samples
# training error=3.5004081470125628 test error=4.135462291948714
# training accuracy=0.6487148346506859 test accuracy=0.6398821374532133
# Elapsed time: 48.4871 seconds
# feature 231 : gene 16295  4373 samples
# training error=3.4824894976805303 test error=4.141435056143983
# training accuracy=0.6490333884165886 test accuracy=0.6405192323007087
# Elapsed time: 47.9404 seconds
# feature 232 : gene 3458  4389 samples
# training error=3.4933402353315945 test error=4.037031138010671
# training accuracy=0.6501881458179863 test accuracy=0.6408377797244564
# Elapsed time: 48.0193 seconds
# feature 233 : gene 7337  4404 samples
# training error=3.474605291974436 test error=4.111332324599825
# training accuracy=0.6511039878949569 test accuracy=0.6420323325635104
# Elapsed time: 48.5212 seconds
# feature 234 : gene 18842  4421 samples
# training error=3.4792044119696577 test error=4.074301186589153
# training accuracy=0.6508849821808987 test accuracy=0.6421916062753843
# Elapsed time: 123.1886 seconds
# feature 235 : gene 6164  4438 samples
# training error=3.469607979771836 test error=4.067930238114199
# training accuracy=0.650805343739423 test accuracy=0.6425897905550689
# Elapsed time: 48.2461 seconds
# feature 236 : gene 20853  4454 samples
# training error=3.4893782228681784 test error=4.045074460460301
# training accuracy=0.6519202819200828 test accuracy=0.6444214382416182
# Elapsed time: 118.2335 seconds
# feature 237 : gene 1645  4473 samples
# training error=3.4389471798036912 test error=4.003344747949351
# training accuracy=0.6517809146475003 test accuracy=0.6456159910806721
# Elapsed time: 47.6337 seconds
# feature 238 : gene 24473  4490 samples
# training error=3.440539948633205 test error=3.9600222983196622
# training accuracy=0.6522189260756167 test accuracy=0.6453770805128614
# Elapsed time: 122.4153 seconds
# feature 239 : gene 276  4505 samples
# ...
# Elapsed time: 163.9383 seconds
# feature 424 : gene 3516  7213 samples
# training error=2.866565791307464 test error=3.5197101218443896
# training accuracy=0.7034861727755988 test accuracy=0.6900533566934778
# Elapsed time: 169.6832 seconds
# feature 425 : gene 24684  7225 samples
# training error=2.8603141736516218 test error=3.4852273632237
# training accuracy=0.7039241842037152 test accuracy=0.6899737198375409
# Elapsed time: 155.9931 seconds
# feature 426 : gene 4333  7239 samples
# training error=2.816672307722938 test error=3.533328024209604
# training accuracy=0.7043223764110936 test accuracy=0.6892569881341085
# Elapsed time: 171.3084 seconds
# feature 427 : gene 11156  7255 samples
# training error=2.816990861488841 test error=3.550768495659791
# training accuracy=0.704501562904414 test accuracy=0.6890977144222347
# Elapsed time: 168.8168 seconds
# feature 428 : gene 7093  7267 samples
# training error=2.802257749815836 test error=3.5250457911921638
# training accuracy=0.7048201166703167 test accuracy=0.6881420721509914
# Elapsed time: 167.4099 seconds
# feature 429 : gene 17047  7277 samples
# training error=2.809385390327911 test error=3.5627936609062676
# training accuracy=0.7049395743325303 test accuracy=0.6890180775662977
# Elapsed time: 183.7351 seconds
# feature 430 : gene 15138  7291 samples
# training error=2.8247755191430906 test error=3.5628732977622044
# training accuracy=0.7050391223843749 test accuracy=0.6897348092697301
# Elapsed time: 159.0333 seconds
# feature 431 : gene 11087  7305 samples
# training error=2.7997292292989826 test error=3.5613601974994027
# training accuracy=0.705536862643598 test accuracy=0.6901329935494147
# Elapsed time: 165.4984 seconds
# feature 432 : gene 25057  7321 samples
# training error=2.7696657176419057 test error=3.5185952058612724
# training accuracy=0.7052581280984331 test accuracy=0.689814446125667
# Elapsed time: 163.4201 seconds
# feature 433 : gene 17689  7335 samples
# training error=2.7485416210404763 test error=3.5702795253643385
# training accuracy=0.7053178569295399 test accuracy=0.6897348092697301
# Elapsed time: 175.1285 seconds
# feature 434 : gene 16138  7349 samples
# training error=2.7709797519262547 test error=3.560245281516286
# training accuracy=0.705278037708802 test accuracy=0.6896551724137931
# Elapsed time: 173.4003 seconds
# feature 435 : gene 9551  7360 samples
# training error=2.756226730642881 test error=3.603886278569722
# training accuracy=0.7055169530332291 test accuracy=0.6901329935494147
# Elapsed time: 167.3494 seconds
# feature 436 : gene 16259  7373 samples
# training error=2.763215003882374 test error=3.543441904913594
# training accuracy=0.7057359587472873 test accuracy=0.6899737198375409
# Elapsed time: 166.8123 seconds
# feature 437 : gene 18052  7387 samples
# training error=2.750970593505485 test error=3.5749780998646172
# training accuracy=0.7059549644613455 test accuracy=0.6902922672612886
# Elapsed time: 169.4326 seconds
# feature 438 : gene 15372  7397 samples
# training error=2.779202421008621 test error=3.621645297443657
# training accuracy=0.7060545125131901 test accuracy=0.6902922672612886
# Elapsed time: 157.5867 seconds
# feature 439 : gene 7790  7409 samples
# training error=2.7577597706412886 test error=3.6417934219956996
# training accuracy=0.7069703545901607 test accuracy=0.6898940829816039
# Elapsed time: 163.7232 seconds
# feature 440 : gene 22396  7423 samples
# training error=2.7434049415652937 test error=3.5593692761009796
# training accuracy=0.7065920719931511 test accuracy=0.6918053675240902
# Elapsed time: 156.6941 seconds
# feature 441 : gene 12747  7437 samples
# training error=2.7341469727437433 test error=3.5813490483395714
# training accuracy=0.706910625759054 test accuracy=0.691964641235964
# Elapsed time: 177.3368 seconds
# feature 442 : gene 10001  7451 samples
# training error=2.724411173273339 test error=3.621645297443657
# training accuracy=0.7068907161486849 test accuracy=0.6921239149478379
# Elapsed time: 176.5147 seconds
# feature 443 : gene 3654  7466 samples
# training error=2.7276962589842118 test error=3.602452815162857
# training accuracy=0.7073287275768013 test accuracy=0.6927610097953333
# Elapsed time: 174.2830 seconds
# feature 444 : gene 3286  7477 samples
# training error=2.702669878750473 test error=3.579597037508959
# training accuracy=0.7074083660182771 test accuracy=0.6922831886597117
# Elapsed time: 172.1029 seconds
# feature 445 : gene 15031  7487 samples
# training error=2.7487008979234275 test error=3.5763319264155453
# training accuracy=0.7073486371871702 test accuracy=0.6916460938122163
# Elapsed time: 177.3234 seconds
# feature 446 : gene 17848  7499 samples
# training error=2.7529416449320085 test error=3.5095962411404
# training accuracy=0.7074083660182771 test accuracy=0.691964641235964
# Elapsed time: 173.6290 seconds
# feature 447 : gene 872  7514 samples
# training error=2.7543353176578336 test error=3.5239308752090466
# training accuracy=0.7072889083560635 test accuracy=0.6922035518037748
# Elapsed time: 160.4571 seconds
# feature 448 : gene 18497  7524 samples
# training error=2.7631154558305293 test error=3.5552281595922595
# training accuracy=0.7073486371871702 test accuracy=0.6922831886597117
# Elapsed time: 187.3027 seconds
# feature 449 : gene 15933  7535 samples
# training error=2.730782248591395 test error=3.570836983355897
# training accuracy=0.7077468293945487 test accuracy=0.6920442780919009
# Elapsed time: 180.1981 seconds
# feature 450 : gene 19457  7547 samples
# training error=2.719115216915205 test error=3.4788564147487455
# training accuracy=0.7075875525115973 test accuracy=0.6920442780919009
# Elapsed time: 171.8614 seconds
# feature 451 : gene 22400  7560 samples
# training error=2.7276564397634737 test error=3.555865254439755
# training accuracy=0.7080056543293448 test accuracy=0.6922831886597117
# Elapsed time: 185.4297 seconds
# feature 452 : gene 20813  7572 samples
# training error=2.738268262090111 test error=3.5459106474476387
# training accuracy=0.7080454735500826 test accuracy=0.6921239149478379
# Elapsed time: 168.1226 seconds
# feature 453 : gene 14228  7583 samples
# training error=2.737710792999781 test error=3.5262403440312178
# training accuracy=0.7082843888745097 test accuracy=0.6921239149478379
# Elapsed time: 189.2630 seconds
# feature 454 : gene 11603  7596 samples
# training error=2.7379297987138393 test error=3.540415704387991
# training accuracy=0.7086626714715193 test accuracy=0.6921239149478379
# Elapsed time: 184.3391 seconds
# feature 455 : gene 8693  7610 samples
# training error=2.7194735899018454 test error=3.4749542088078362
# training accuracy=0.7089015867959464 test accuracy=0.6920442780919009
# Elapsed time: 183.3314 seconds
# feature 456 : gene 4235  7621 samples
# training error=2.737690883389412 test error=3.479573146452178
# training accuracy=0.7089613156270532 test accuracy=0.6934777414987656
# Elapsed time: 183.5041 seconds
# feature 457 : gene 20367  7634 samples
# training error=2.739482748322615 test error=3.5262403440312178
# training accuracy=0.7091006828996357 test accuracy=0.6937166520665764
# Elapsed time: 193.6577 seconds
# feature 458 : gene 16283  7648 samples
# training error=2.7442212355904196 test error=3.515728279047543
# training accuracy=0.7089214964063153 test accuracy=0.6933981046428287
# Elapsed time: 171.5628 seconds
# feature 459 : gene 7526  7658 samples
# training error=2.7426483763712746 test error=3.510551883411643
# training accuracy=0.7089214964063153 test accuracy=0.6939555626343872
# Elapsed time: 177.1538 seconds
# feature 460 : gene 12146  7671 samples
# training error=2.7821291337328526 test error=3.4931910488173927
# training accuracy=0.7092002309514803 test accuracy=0.6929202835072071
# Elapsed time: 174.3848 seconds
# feature 461 : gene 10444  7681 samples
# training error=2.77199514205507 test error=3.5188341164290833
# training accuracy=0.7096183327692277 test accuracy=0.6939555626343872
# Elapsed time: 190.6764 seconds
# feature 462 : gene 7587  7692 samples
# training error=2.7706014693292453 test error=3.4998805447160946
# training accuracy=0.7097975192625481 test accuracy=0.693079557219081
# Elapsed time: 175.4230 seconds
# feature 463 : gene 11214  7706 samples
# training error=2.788241384116113 test error=3.4957394282073744
# training accuracy=0.7096183327692277 test accuracy=0.6936370152106395
# Elapsed time: 168.6597 seconds
# feature 464 : gene 5692  7718 samples
# training error=2.7489199036374856 test error=3.4822807995540335
# training accuracy=0.7096581519899655 test accuracy=0.6939555626343872
# Elapsed time: 174.8241 seconds
# feature 465 : gene 25333  7728 samples
# training error=2.7301451410595896 test error=3.493668869953014
# training accuracy=0.7094988751070141 test accuracy=0.694114836346261
# Elapsed time: 177.4309 seconds
# feature 466 : gene 4001  7741 samples
# training error=2.736556035598383 test error=3.39268933662499
# training accuracy=0.7095785135484899 test accuracy=0.6944333837700087
# Elapsed time: 177.9682 seconds
# feature 467 : gene 5758  7754 samples
# training error=2.7380492563760526 test error=3.414669108863582
# training accuracy=0.7096183327692277 test accuracy=0.6943537469140718
# Elapsed time: 168.9599 seconds
# feature 468 : gene 9376  7765 samples
# training error=2.761920879208394 test error=3.3901409572350083
# training accuracy=0.7094590558862763 test accuracy=0.6937166520665764
# Elapsed time: 171.3838 seconds
# feature 469 : gene 7288  7776 samples
# training error=2.7562466402532504 test error=3.3961933582862147
# training accuracy=0.7101558922491887 test accuracy=0.6944333837700087
# Elapsed time: 180.3485 seconds
# feature 470 : gene 9275  7787 samples
# training error=2.748322615326418 test error=3.4419845504499484
# training accuracy=0.7100563441973441 test accuracy=0.6946722943378195
# Elapsed time: 186.1643 seconds
# feature 471 : gene 21884  7797 samples
# training error=2.7431859358512356 test error=3.4527355260014336
# training accuracy=0.7101558922491887 test accuracy=0.6948315680496934
# Elapsed time: 187.7553 seconds
# feature 472 : gene 3786  7808 samples
# training error=2.7229577717164073 test error=3.356852751453373
# training accuracy=0.7101957114699265 test accuracy=0.6948315680496934
# Elapsed time: 176.3303 seconds
# feature 473 : gene 4163  7820 samples
# training error=2.735341549365879 test error=3.3590029465636695
# training accuracy=0.7102753499114023 test accuracy=0.6943537469140718
# Elapsed time: 186.1949 seconds
# feature 474 : gene 10312  7832 samples
# training error=2.74013976546479 test error=3.3645775264792546
# training accuracy=0.7104943556254604 test accuracy=0.6949112049056303
# Elapsed time: 180.5859 seconds
# feature 475 : gene 24068  7846 samples
# training error=2.788778943596074 test error=3.3859202038703513
# training accuracy=0.7104744460150915 test accuracy=0.6956279366090626
# Elapsed time: 176.7600 seconds
# feature 476 : gene 16240  7859 samples
# training error=2.7947319170963825 test error=3.3748506808951184
# training accuracy=0.7104943556254604 test accuracy=0.6951501154734411
# Elapsed time: 179.0285 seconds
# feature 477 : gene 6222  7873 samples
# training error=2.7769128158161944 test error=3.340208648562555
# training accuracy=0.7106735421187808 test accuracy=0.6954686628971888
# Elapsed time: 182.7674 seconds
# feature 478 : gene 19323  7888 samples
# training error=2.795369024628188 test error=3.415784024846699
# training accuracy=0.7109124574432079 test accuracy=0.6960261208887473
# Elapsed time: 184.5518 seconds
# feature 479 : gene 1373  7900 samples
# training error=2.7896947856730443 test error=3.4116429083379787
# training accuracy=0.7106735421187808 test accuracy=0.6958668471768734
# Elapsed time: 174.8928 seconds
# feature 480 : gene 2178  7914 samples
# training error=2.79218348696916 test error=3.422792068169149
# training accuracy=0.7107332709498875 test accuracy=0.6959464840328103
# Elapsed time: 189.1082 seconds
# feature 481 : gene 12493  7926 samples
# training error=2.7623389810261414 test error=3.5130206259456878
# training accuracy=0.7115296553646445 test accuracy=0.6955482997531257
# Elapsed time: 188.0479 seconds
# feature 482 : gene 4643  7936 samples
# training error=2.7524439046727855 test error=3.557617265270367
# training accuracy=0.7113504688713241 test accuracy=0.6957872103209365
# Elapsed time: 192.1791 seconds
# feature 483 : gene 6172  7952 samples
# training error=2.721703466263165 test error=3.4707334554431792
# training accuracy=0.7114500169231688 test accuracy=0.6965835788803058
# Elapsed time: 177.9690 seconds
# feature 484 : gene 13587  7962 samples
# training error=2.7128436896489934 test error=3.4779007724775024
# training accuracy=0.711927847572023 test accuracy=0.6977781317193598
# Elapsed time: 183.2836 seconds
# feature 485 : gene 17882  7977 samples
# training error=2.7126047743245665 test error=3.443656924424624
# training accuracy=0.7119477571823919 test accuracy=0.6981763159990444
# Elapsed time: 176.9147 seconds
# feature 486 : gene 26335  7990 samples
# training error=2.7117884802994405 test error=3.4239069841522656
# training accuracy=0.7124454974416151 test accuracy=0.6971410368718644
# Elapsed time: 188.0309 seconds
# feature 487 : gene 893  8003 samples
# training error=2.7152527525036336 test error=3.417934219956996
# training accuracy=0.7122862205586636 test accuracy=0.6974595842956121
# Elapsed time: 177.5330 seconds
# feature 488 : gene 25438  8011 samples
# training error=2.7513886953232327 test error=3.447320219797722
# training accuracy=0.7126645031556732 test accuracy=0.6969021263040536
# Elapsed time: 191.7625 seconds
# feature 489 : gene 9251  8026 samples
# training error=2.717522448085691 test error=3.3633033367842637
# training accuracy=0.7123857686105083 test accuracy=0.6971410368718644
# Elapsed time: 183.0289 seconds
# feature 490 : gene 6466  8036 samples
# training error=2.7039042745933464 test error=3.3606753205383453
# training accuracy=0.7125052262727218 test accuracy=0.6974595842956121
# Elapsed time: 176.8206 seconds
# feature 491 : gene 10472  8048 samples
# training error=2.683775658510363 test error=3.3547821931990125
# training accuracy=0.7131622434148964 test accuracy=0.697539221151549
# Elapsed time: 202.6497 seconds
# feature 492 : gene 6897  8061 samples
# training error=2.700201087064726 test error=3.4097316237954924
# training accuracy=0.7134608875704302 test accuracy=0.6984152265668552
# Elapsed time: 189.6074 seconds
# feature 493 : gene 7352  8077 samples
# training error=2.7135803452326437 test error=3.3954766265827825
# training accuracy=0.71328170107711 test accuracy=0.6984152265668552
# Elapsed time: 184.7648 seconds
# feature 494 : gene 16884  8090 samples
# training error=2.7268998745694546 test error=3.3690371904117224
# training accuracy=0.7133812491289545 test accuracy=0.6992115951262244
# Elapsed time: 190.6873 seconds
# feature 495 : gene 16866  8099 samples
# training error=2.7365162163776455 test error=3.399299195667755
# training accuracy=0.7132219722460031 test accuracy=0.698654137134666
# Elapsed time: 204.1198 seconds
# feature 496 : gene 362  8108 samples
# training error=2.707308817966432 test error=3.3512781715377877
# training accuracy=0.7138590797778087 test accuracy=0.6989726845584137
# Elapsed time: 185.6880 seconds
# feature 497 : gene 14911  8119 samples
# training error=2.7051983992673265 test error=3.3871147567094053
# training accuracy=0.7139984470503912 test accuracy=0.6988134108465398
# Elapsed time: 184.8864 seconds
# feature 498 : gene 13786  8136 samples
# training error=2.7280546319708523 test error=3.4302779326272197
# training accuracy=0.7141378143229737 test accuracy=0.6993708688380983
# Elapsed time: 197.7709 seconds
# feature 499 : gene 1530  8146 samples
# training error=2.7085631234196748 test error=3.530620371107749
# training accuracy=0.7142174527644494 test accuracy=0.6984152265668552
# Total run time: 46435.6403 seconds
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5593/3308914115.py in <module>
#      15     text_create(path,'accuracy',train_scores+test_scores)
#      16     text_create(path,'num_samples_list',num_samples_list)
# ---> 17     text_create(path,'genes_name',gene[feature_selected])
#      18     text_create(path,'elapsed_time',elapsed_time)
#      19     text_create(path,'memory',memorys)
#
# NameError: name 'gene' is not defined

# %%
gluData.var_names[feature_selected[0:350]]
# Out:
# Index(['Spns3', '4932411N23Rik', '2810002D19Rik', 'Erbb4', 'Dock10', 'Prlr',
#        'Nrp2', 'Gpc5', 'Ebf1', 'Kcnip1',
#        ...
#        'Tor1aip1', 'Morn2', 'Tmtc4', 'AW551984', 'Gm4924', 'Mitf', 'Ttc28',
#        'Fam189a2', 'Hpcal4', 'Col26a1'],
#       dtype='object', name='gene', length=350)

# %%
clusterDict = {350 : gene[feature_selected[0:350]], 500 : gene[feature_selected]}

with open("../Data/activeSVM_p11_p14_panel.pickle", 'wb') as f:
    pickle.dump(clusterDict, f)
