# %% [markdown]
# ## Filter MERSCOPE unsuitable genes
#
# Want to create lists of genes that shouldn't be used for gene panel selection, due to either proven track record of poor performance or unsuitable length

# %%
import pickle

# %%
# These genes are from an email from Brian Long labelling them as "the worst offender" 
# [the "perhaps less bad" genes are not included here]
previousGenes = ['Cdh7', 'Col25a1', 'Foxp2', 'Gabra1', 'Gabrg1', 'Gad1', 'Inpp4b', 'Lypd1', 'Maob', 
            'Nell1', 'Pantr1', 'Pkib', 'Shisa9', 'Sox5', 'Thsd7a', 'Tmem196',  'Tunar']

with open("../Data/previousGenes.pickle", "wb") as f:
    pickle.dump(previousGenes,f)

# %% [markdown]
# ## Gene length via ensembl .gtf genome
#
# Search individual genes: https://www.ncbi.nlm.nih.gov/gene/21419

# %%
import numpy as np
import pandas as pd
import anndata as ad
import scanpy as sc
import json
import pickle
import numpy as np
from gtfparse import read_gtf

# %%
# Load in pre-processed data from glutamatergic class designation, subclass to all rank_gene_groups already performed
gluData = sc.read("../Data/devData.h5ad")
# Out:
# C:\Users\mathew.summers\Anaconda3\envs\scanpy1.9\lib\site-packages\anndata\_core\anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
# Get gene names from scRNAseq data set
seqGenes = list(gluData.var_names)

# Load genome file as dataframe
mouseGTF = read_gtf("../Data/Mouse Genome/Mus_musculus.GRCm39.106.gtf")

# Subset dataframe to entries labeled as genes [df.feature.unique() to view possible entries, e.g. transcript]
mouseGenes = mouseGTF[mouseGTF.feature == "gene"]
# Out:
# C:\Users\mathew.summers\Anaconda3\envs\scanpy1.9\lib\site-packages\gtfparse\read_gtf.py:82: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   chunk_iterator = pd.read_csv(
# C:\Users\mathew.summers\Anaconda3\envs\scanpy1.9\lib\site-packages\gtfparse\read_gtf.py:82: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   chunk_iterator = pd.read_csv(
# INFO:root:Extracted GTF attributes: ['gene_id', 'gene_version', 'gene_name', 'gene_source', 'gene_biotype', 'transcript_id', 'transcript_version', 'transcript_name', 'transcript_source', 'transcript_biotype', 'tag', 'transcript_support_level', 'exon_number', 'exon_id', 'exon_version', 'ccds_id', 'protein_id', 'protein_version']

# %%
# Do a quick and dirty count of how many seqGene names don't match a gene within the database
a = 0
for gene in seqGenes:
    a += not(gene in list(mouseGenes.gene_name))

print(a) # Should be ~750 out of ~40,000 in development data set, not bad
# Out:
# 729

# %%
# Get length of each genome entry
mouseGenes["length"] = mouseGenes.end - mouseGenes.start
# Out:
# C:\Users\mathew.summers\AppData\Local\Temp\ipykernel_14616\946826167.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mouseGenes["length"] = mouseGenes.end - mouseGenes.start

# %%
# Want to find which genes within the list of seqGenes is less than 3kb long

shortGenes = list();

for gene in seqGenes:
    # First check for genes matching sequencing gene name
    geneDF = mouseGenes[mouseGenes.gene_name == gene]
    if len(geneDF) > 0:
        # Then check if such genes are shorter than 3kb 
        # [some genes have multiple listings, just be conservative and use largest]
        if np.max(geneDF.length < 3000):
            shortGenes.append(gene)
    
print('Found ', len(shortGenes), ' short genes.')
# Out:
# Found  5696  short genes.

# %%
with open("../Data/shortGenes.pickle", "wb") as f:
    pickle.dump(shortGenes,f)

# %%
list(set(seqGenes) - set(shortGenes))
# Out:
# ['Gm29622',
#  '2810408A11Rik',
#  'Fgf18',
#  'Gm26811',
#  'Dnajb9',
#  'Crygs',
#  'Aicda',
#  'C87487',
#  'Mamld1',
#  'Ifi208',
#  'Gm28672',
#  'Gmps',
#  'Cyp2g1',
#  'Macrod1',
#  'Ttll3',
#  'Papss1',
#  'Hist1h3a',
#  'Pon1',
#  'Btnl10',
#  'Rpl18',
#  'Gm26685',
#  '4930434J06Rik',
#  'Gpc2',
#  'Mfsd7a',
#  'Pigq',
#  'Dnajc17',
#  'Lysmd4',
#  'Gm16029',
#  'Gm4724',
#  'Gm40916',
#  'Rs1',
#  'Vmn2r72',
#  'Gm15608',
#  'Cfap410',
#  'Nkpd1',
#  'Bok',
#  'Hnf4g',
#  'Gm42817',
#  'Snrnp200',
#  'Rnf225',
#  'Usp43',
#  'B230217J21Rik',
#  'Gm16253',
#  'Olfr193',
#  'Cycs',
#  'Gm44127',
#  'Emsy',
#  'Ptk2',
#  'Gm3727',
#  'Gm33195',
#  'Gm31831',
#  'Vcpip1',
#  'C230099D08Rik',
#  'Zfp703',
#  'Pi15',
#  'Bcl2l12',
#  'Camk2g',
#  'Rab11fip2',
#  'Gm36043',
#  'Wdr12',
#  'Gm31182',
#  'Crebzf',
#  'Zfp36l1',
#  'Msrb2',
#  'Cerkl',
#  'Kif21a',
#  'Gm15346',
#  'Gm50350',
#  'AY761184',
#  'Vmn2r1',
#  'Cabcoco1',
#  'Fastkd2',
#  'Gm6710',
#  'Psd3',
#  'Pbx3',
#  'Eapp',
#  '1810021B22Rik',
#  'Lgi2',
#  'Hist1h3g',
#  'Gusb',
#  'Rnf126',
#  'Xist',
#  'Sim2',
#  '5430416N02Rik',
#  'Elmod1',
#  'Fabp12',
#  'Phf20l1',
#  'Acad9',
#  'Gm6093',
#  'Ly96',
#  'Olfr118',
#  'Senp6',
#  'Slc38a1',
#  'Klra10',
#  'Dcps',
#  'Gm4881',
#  'Hoxc13',
#  'Agbl2',
#  'Trim30c',
#  'Lig4',
#  'Gm43000',
#  'Tchh',
#  'Fam221b',
#  'Gm37799',
#  'Gm20535',
#  'Lpar4',
#  'Zfp185',
#  'Ambn',
#  'Gm28081',
#  'Irf5',
#  'Spint4',
#  'Vmn1r28',
#  'Hspb8',
#  'Gm36536',
#  'Scn10a',
#  'Pdk1',
#  'Reep5',
#  'Hgs',
#  'Zmym1',
#  'Zfp616',
#  'Pde7a',
#  'Gm21677',
#  'Zfp236',
#  'Eps8l2',
#  'Olfr1166',
#  'Samd9l',
#  'Gm15594',
#  'Mptx2',
#  'Adora2b',
#  'Tmem128',
#  'Atxn7l1',
#  '4933433G15Rik',
#  'Olfr111',
#  'Zfp14',
#  'Tmprss11e',
#  'L1td1',
#  'Gm8212',
#  'Ophn1',
#  '1700100I10Rik',
#  'Tcf4',
#  'Rab3b',
#  'Pcp4l1',
#  'Idh3a',
#  'Kcnmb2',
#  'Olfr168',
#  'Rgs12',
#  'Gm49224',
#  'Cyp3a13',
#  'Stpg2',
#  'Gm50016',
#  '2310022A10Rik',
#  'Gm48170',
#  'Epx',
#  'Bpifb3',
#  'Igsf6',
#  'Pura',
#  'Gm16263',
#  'Gm3896',
#  'Gm3248',
#  'Paip2',
#  'Esp36',
#  'Gprc5c',
#  'Gm10964',
#  '4930407I19Rik',
#  'Rgs9',
#  'Pcsk2os2',
#  'Csde1',
#  'Nipsnap1',
#  'Smim10l1',
#  'Gm47827',
#  'Gm31513',
#  'Prph',
#  'Ehd3',
#  'Gm14743',
#  'Gatad1',
#  'Gm15755',
#  '1700027A15Rik',
#  'Lingo2',
#  'Gm20628',
#  'Gemin4',
#  'Pip5k1a',
#  'Olfr825',
#  'Ppil6',
#  'Chac2',
#  'Gm50227',
#  '1700003D09Rik',
#  'Wfdc15b',
#  'Gm16118',
#  'Zfp599',
#  'Diaph2',
#  'Olfr847',
#  'Cfap61',
#  '4930556G22Rik',
#  'Necap2',
#  'Cnot3',
#  'Gm3898',
#  'Gm15716',
#  'Gm5092',
#  'Fosb',
#  '5830408C22Rik',
#  'Gm12977',
#  'Kcnk12',
#  'D830030K20Rik',
#  'Gm14066',
#  'Cpt1c',
#  'Drg2',
#  'Aldh4a1',
#  'Cenpa',
#  'Sft2d1',
#  'Htr3b',
#  'Prr33',
#  'Ss18',
#  'Wdr72',
#  'Kcnip2',
#  'Glipr1l2',
#  '2010009K17Rik',
#  'Flywch2',
#  'Gm48830',
#  'Brix1',
#  '5830418P13Rik',
#  'D930007P13Rik',
#  'Gm13539',
#  'Arpc4',
#  'Pak2',
#  '4930419G24Rik',
#  'Olfr922',
#  '6030469F06Rik',
#  'Haus7',
#  'D030051J21Rik',
#  'Spx',
#  'Cyth2',
#  'Gm16556',
#  'Gm14326',
#  '4921509O07Rik',
#  'Catsper1',
#  'Fancg',
#  'BC051142',
#  'Panct2',
#  'Gm31087',
#  'Cstad',
#  'Prss41',
#  'Ptprn2',
#  'Gm40604',
#  '9530082P21Rik',
#  'D630045J12Rik',
#  'Cybc1',
#  'Grm1',
#  'Gm4230',
#  'Slc30a7',
#  'Pald1',
#  'Vmn1r71',
#  'Gm33053',
#  'Nckap1l',
#  'Map2k3os',
#  'Sp7',
#  'Gm17768',
#  'Gm12968',
#  'Gm21954',
#  'Gm17767',
#  'Zscan4c',
#  'Zfp27',
#  'Mpp3',
#  '9430060I03Rik',
#  'Colq',
#  'Kcnab2',
#  'Gm34455',
#  'Nelfcd',
#  '1700110I07Rik',
#  'Tor2a',
#  'Gm26885',
#  'Ccdc124',
#  'Cyp2b10',
#  'Heatr3',
#  'Ncoa7',
#  'Fam228a',
#  'Gmpr2',
#  'Rtl5',
#  'Dclre1a',
#  'Olfr1351',
#  'Acp5',
#  'Rbl2',
#  'Cyp2d40',
#  'Cysltr2',
#  'Cyp2b9',
#  'Txndc5',
#  'Tex52',
#  'Nlrp9b',
#  'Nubp1',
#  'Grik1',
#  'Cplx2',
#  'Cfhr1',
#  'Hlx',
#  'Xpo6',
#  'Coq8b',
#  'Olfr535',
#  'Gm31645',
#  'Gm29480',
#  'Gm46378',
#  'Gm29569',
#  '1700082M22Rik',
#  'Rasa1',
#  'Gm16316',
#  'Aadacl3',
#  'Gnas',
#  'Gm2233',
#  'Emd',
#  'Nqo2',
#  'Rian',
#  'Cox11',
#  'Krtcap2',
#  'Ino80c',
#  'Ccr4',
#  'Stk36',
#  'Gskip',
#  'Cst10',
#  'Olfr347',
#  'Agps',
#  'Fbn1',
#  'Gm14496',
#  'Gm50395',
#  'A730049H05Rik',
#  'Trmt9b',
#  'Olfr1480',
#  'AU040320',
#  'Gm42997',
#  'Pou4f2',
#  'Anxa10',
#  'Ash2l',
#  'Ctsf',
#  'Gm48419',
#  'Dnajc21',
#  'En1',
#  'Mllt1',
#  'Cpe',
#  'Pygb',
#  'Gm32442',
#  'Gm3002',
#  'Gm26813',
#  'Gm46328',
#  'C130080G10Rik',
#  'Gm35028',
#  'Prr15l',
#  'H2-M10.6',
#  'Ak5',
#  'Gm5608',
#  'Gm19792',
#  'Slc25a40',
#  'Gm45869',
#  'Gm42931',
#  'Dmrt1i',
#  'Katnal1',
#  'Cdiptos',
#  'Tns3',
#  'A930001M01Rik',
#  'C87198',
#  'Ets2',
#  'Gp5',
#  'Aplnr',
#  'Gm49106',
#  'Tatdn1',
#  'Gm43342',
#  'Gatd3a',
#  '4933432I03Rik',
#  'Kansl1l',
#  'Pkp2',
#  'Cyp4a32',
#  'Tshz1',
#  'Cdc42bpb',
#  'Gm36377',
#  'Mrpl32',
#  'Fkbp8',
#  'Rab13',
#  'Mthfd1',
#  'Mcph1',
#  'Gm5771',
#  'Gm26511',
#  'Gm50270',
#  'Mss51',
#  '1700049E15Rik',
#  'Gm46404',
#  'Stk32c',
#  '1810062G17Rik',
#  'Fancd2os',
#  'D030056L22Rik',
#  'Gm49878',
#  'Pelp1',
#  'Uck2',
#  'Gm37451',
#  'Lrrc75a',
#  '1700020D12Rik',
#  '1110020A21Rik',
#  'Gm26692',
#  'Plcb4',
#  'Cenpm',
#  'Cnmd',
#  'Vmn1r11',
#  'Bambi',
#  'Mybphl',
#  'Plch1',
#  'Gm15962',
#  'Oxtr',
#  'Slc39a8',
#  'Cacna2d4',
#  'Fam181a',
#  'Spocd1',
#  'Smok3a',
#  'Zfp760',
#  'Hand2',
#  'Xylt2',
#  'Gm26782',
#  'E330009J07Rik',
#  'Gabra1',
#  'Carnmt1',
#  'Lipo2',
#  'Gpx8',
#  'Slc22a16',
#  'Gm30784',
#  'Treh',
#  'Dtnbos',
#  'Gm31343',
#  'Dazap2',
#  'Krt15',
#  'Cav3',
#  'Mmab',
#  'Gm33460',
#  'Olfr132',
#  'Hck',
#  'AA386476',
#  'Cldn34b4',
#  'Gm15890',
#  'Vmn1r46',
#  'Dpp7',
#  'Plxdc1',
#  'Gm45901',
#  'Vmn2r24',
#  'Kif15',
#  'Gm12059',
#  'Gm49175',
#  'Gm39214',
#  'Frg1',
#  'Gm26944',
#  'Zfp791',
#  'Gm11739',
#  'Aldh1l1',
#  'Fam227b',
#  'Six4',
#  'Mre11a',
#  'Gm48775',
#  'Ifit2',
#  'Gm36738',
#  'Zfp965',
#  'Gm4251',
#  'Cxcl9',
#  'Mea1',
#  'Bpnt1',
#  '1700069L16Rik',
#  'Tubgcp6',
#  'Gm26995',
#  'B230359F08Rik',
#  '2310047D07Rik',
#  'BC055402',
#  'Rpl35',
#  'Mettl25',
#  'Dusp11',
#  'Zfp981',
#  'Pcyt1b',
#  'Nxt1',
#  'Prr29',
#  'Hddc2',
#  'Gm28823',
#  'Cmpk1',
#  'Kbtbd11',
#  'Rrnad1',
#  'C87436',
#  'Acmsd',
#  'Szrd1',
#  'Cyp2s1',
#  'CR974488.1',
#  'Gba2',
#  'Gm49756',
#  'Eml3',
#  'Banf2os',
#  'Spcs3',
#  'Odaph',
#  'Etv1',
#  'Eif4g2',
#  'Sncaip',
#  'Pgrmc1',
#  'Gm19510',
#  'Gdf5',
#  '1700031A10Rik',
#  'Gm36487',
#  'Lrrc34',
#  'Gm26743',
#  'Gm13794',
#  'Ccdc71',
#  'Chtf18',
#  'Txn2',
#  'Gm14144',
#  'Olfr487',
#  'Gm13431',
#  'Tmem8',
#  'Pus1',
#  'Gm33969',
#  'Clca3b',
#  'A230103J11Rik',
#  'Gpr161',
#  'Rnmt',
#  'Arhgef28',
#  'Slc35a4',
#  'Derl1',
#  'Adamts13',
#  'Tcf3',
#  'Tmem97',
#  'Myh7',
#  'Gm8066',
#  'Bace2',
#  'Ppm1d',
#  'Gm13446',
#  'Olfr1168',
#  'Slc37a2',
#  'F12',
#  'Gm34510',
#  'Mpg',
#  'Gm31814',
#  'Mfng',
#  'Htr2c',
#  '9630013A20Rik',
#  'Gcg',
#  'Gm48884',
#  'Gm4265',
#  'Snx27',
#  'Gm3137',
#  '9230020A06Rik',
#  '4930511M18Rik',
#  'Ces1g',
#  'Gtf3c5',
#  'Alas1',
#  'Gm5893',
#  'Gm11213',
#  'Proser2',
#  'Grn',
#  'Sptlc2',
#  'Sh3bgrl2',
#  'Gm48441',
#  'Gm50294',
#  'Mmd2',
#  'A930006I01Rik',
#  'Gm46392',
#  'Adra2b',
#  'Gm45672',
#  'Gm5346',
#  'Clec2g',
#  'Il20ra',
#  'Tuba8',
#  'Platr25',
#  'Bend7',
#  'Acads',
#  'Sult1d1',
#  'Vmn2r77',
#  'Gm49403',
#  'Hhipl1',
#  'Wnt2b',
#  'Slc28a2',
#  'Ssxb2',
#  '0610030E20Rik',
#  'Mon1b',
#  'Mapk13',
#  'Gucy2d',
#  'Spatc1',
#  'Gm12473',
#  'Mcm6',
#  'Gm39436',
#  'Gm47593',
#  'Ndufb2',
#  'Smr2',
#  'Zfp948',
#  'Tnfrsf21',
#  'Fubp3',
#  'Pot1a',
#  'Gm2670',
#  'Rcsd1',
#  'Gm5148',
#  'Gm50035',
#  'Mtcp1',
#  'Olfr723',
#  'Olfr644',
#  'Gm28068',
#  '9330159F19Rik',
#  'Rad1',
#  'Gm48656',
#  'Brd2',
#  'Olfr1157',
#  'Akap17b',
#  '6330403L08Rik',
#  'Il11ra2',
#  'Slpi',
#  'Impad1',
#  'Dgcr2',
#  '9030025P20Rik',
#  'Tmem98',
#  'Pi4kb',
#  'Cir1',
#  'Pik3ap1',
#  'Gm20652',
#  'Atp13a3',
#  'Irf7',
#  'Cdk5rap3',
#  'Gm3147',
#  'Zcchc10',
#  'Senp5',
#  'Gm28726',
#  'Gm45902',
#  'Gm16675',
#  'Ccdc116',
#  'Olfr1425',
#  'Dcun1d5',
#  'Gm28407',
#  'Zfp668',
#  'Gm4214',
#  'Lipi',
#  'Klf17',
#  'Gm20387',
#  'Wdr77',
#  'Kdm4c',
#  'Cdc42ep5',
#  'Slx4',
#  'Ube2z',
#  'Lurap1l',
#  'Usp38',
#  'Ancv1r',
#  'Clec4a3',
#  'Il5ra',
#  'Efcab10',
#  '4921528I07Rik',
#  'Mroh6',
#  'Gm48485',
#  'Gm40576',
#  'Hist1h2bn',
#  'Map3k12',
#  'Med17',
#  'Tmem185a',
#  'Hao1',
#  'Snx2',
#  'Fxyd2',
#  'Spata31d1d',
#  'Lrrk1',
#  'Fastk',
#  'Rims1',
#  'Fbxl5',
#  'Mrps16',
#  'Znrd1as',
#  'Hdac4',
#  'BC003965',
#  'Alx1',
#  'Tc2n',
#  'Gm39380',
#  'Olfr205',
#  'Slk',
#  'Cfap58',
#  'Prss29',
#  'Gm44813',
#  'Prdm5',
#  'Senp1',
#  'Gm22219',
#  'Tssk1',
#  'Gm43707',
#  'Zfp82',
#  'Irak1',
#  'Psg22',
#  'Gm20686',
#  'Olfr1487',
#  'Ormdl1',
#  'Vmn1r16',
#  'Gm32369',
#  '4930503F20Rik',
#  'Gm2245',
#  'Fxr1',
#  'Fbxo34',
#  'Dync2li1',
#  'Gm41219',
#  'Vmn2r29',
#  'Fam131a',
#  'Popdc3',
#  'D230025D16Rik',
#  'Gm49198',
#  'Ap2a2',
#  'Gm35549',
#  'D030007L05Rik',
#  'Vmn1r206',
#  'F11',
#  'Vmn1r57',
#  'Gm16579',
#  'Gm3752',
#  'Gckr',
#  'Ctu2',
#  'Vgll2',
#  'Gm11266',
#  'Fam168b',
#  'Ddah1',
#  'Mup1',
#  'Anapc15',
#  'Nras',
#  'Clca4b',
#  '1700123M08Rik',
#  'Nr2c1',
#  'Pgam5',
#  'H2afb3',
#  '4930533P14Rik',
#  'Osbpl11',
#  'H2-Eb2',
#  'Snhg17',
#  'Kctd8',
#  'Myl9',
#  'Nedd1',
#  'Gm11738',
#  'Gm906',
#  'Ccnt2',
#  '2510009E07Rik',
#  'Gm32531',
#  'Limd1',
#  'Acot12',
#  'Kcne3',
#  'Csnk1d',
#  'Lrrc8c',
#  'Sfrp4',
#  'Gm3509',
#  'Rcvrn',
#  'Taldo1',
#  'Zbtb22',
#  'Minpp1',
#  'Rax',
#  'Galnt17',
#  'Tnfrsf8',
#  'Itfg2',
#  'Gm37915',
#  'Txnrd3',
#  'Foxl2os',
#  'Gm6592',
#  'Tes',
#  'Prl2c1',
#  'Gm28490',
#  'Gm5444',
#  'Gm35533',
#  'Kcnab1',
#  'Kif2c',
#  'C920021L13Rik',
#  'Gm11755',
#  'Prdx4',
#  'Gpr141',
#  'Trappc2l',
#  '4930568A12Rik',
#  'Caps2',
#  'Abcc5',
#  'Rnf10',
#  'Cd209a',
#  'Tex30',
#  'Gm44691',
#  'Olfr619',
#  'Gm12670',
#  'Brpf1',
#  'Gm13497',
#  'Il19',
#  '3425401B19Rik',
#  'Gm15597',
#  'Olfr974',
#  'Gm14393',
#  'Gm11659',
#  'Fam104a',
#  'Lzic',
#  'Btbd18',
#  'Gm49692',
#  '6030442K20Rik',
#  'Vmn1r30',
#  'Plxnb2',
#  'Lingo3',
#  'Gm20149',
#  'Gm13982',
#  'Coa4',
#  'Wwc1',
#  'Kcnj13',
#  'A430088P11Rik',
#  'Enkd1',
#  '1700010I14Rik',
#  'Klhl33',
#  'Bhlhe40',
#  'Dgki',
#  '4930478P22Rik',
#  'Gm16551',
#  'Adh7',
#  'Timm23',
#  'Senp8',
#  'Siah3',
#  'Gprc5d',
#  'Akap12',
#  'Hsf2',
#  'Clspn',
#  'Hacd1',
#  'Agr2',
#  'Eps15',
#  'Unc45b',
#  'Zfp964',
#  'Cops7b',
#  'Samsn1',
#  'Nebl',
#  'Gm40761',
#  'Uxt',
#  'Heatr1',
#  'Olfr1028',
#  'Psme4',
#  'Sv2a',
#  'Slc25a35',
#  'Cers2',
#  'Gm42664',
#  'Olfr1431',
#  'Tm4sf5',
#  'Oosp3',
#  'Scgn',
#  'Muc4',
#  'Hmga1',
#  'Zfp637',
#  'Rfc2',
#  'Thbs4',
#  'Gm34517',
#  'Gm13346',
#  'Gm21258',
#  'Marveld3',
#  '4930595L18Rik',
#  'Ehbp1',
#  'Gm28157',
#  'Grm6',
#  'Serpinb9h',
#  'Dars',
#  '5031434C07Rik',
#  'Vmn2r59',
#  'Chrnb4',
#  'Stx7',
#  'Gm29012',
#  'Fam207a',
#  '4933417D19Rik',
#  'Nt5m',
#  'Olfr1537',
#  'Gm35419',
#  'Duxbl3',
#  'Gm10433',
#  'Olfr554',
#  'Txndc15',
#  'Dzip1l',
#  'Morn4',
#  'Tmc3',
#  'Hey1',
#  '2410003L11Rik',
#  'Tmem35a',
#  'Me2',
#  'Ssxb10',
#  'Arap3',
#  'Pitrm1',
#  'Zcchc7',
#  'Zfp846',
#  'Prss58',
#  'Slc7a9',
#  'Rbm15',
#  'Cdk14',
#  'Olfr376',
#  'Gm20476',
#  'Gm10857',
#  'Gm28638',
#  'Gm29880',
#  'Pif1',
#  'Armc12',
#  'Zfp983',
#  'Gm4566',
#  '4933401D09Rik',
#  'Gm34093',
#  'Hdac1',
#  'Psmd9',
#  'Lrrc41',
#  'Adgre4',
#  'Btbd3',
#  'Olfr1006',
#  '3110001I22Rik',
#  'AC140365.1',
#  'Trappc6a',
#  '6530437J22Rik',
#  'Abcc12',
#  '4930511E03Rik',
#  'Gm45666',
#  'Tma16',
#  'Il21r',
#  'Masp2',
#  'Gm41192',
#  'Gm16548',
#  'Strap',
#  'Zfyve21',
#  'Fhod1',
#  'Loxl1',
#  'Rorc',
#  'Akirin1',
#  'Mir100hg',
#  'Grin2b',
#  'Tmem59l',
#  '2310001H17Rik',
#  'Dnaic1',
#  'Stard6',
#  'Magoh',
#  'Smim23',
#  'Gm15663',
#  'Gm8300',
#  'Olfr1378',
#  'Gm20646',
#  'Rps14',
#  'Igfn1',
#  'Cenpl',
#  'Vps13c',
#  'Serpinb9d',
#  'Gpnmb',
#  'Dmrtb1',
#  'Maml1',
#  'Gm29684',
#  'Pxt1',
#  'Mrpl47',
#  'Camta2',
#  'Abt1',
#  'Gm49257',
#  'Olfr816',
#  'Gm12147',
#  'Gm44501',
#  'Far2os2',
#  'Gm550',
#  'Cyp3a25',
#  '5830428M24Rik',
#  'Gm43614',
#  'Arhgap10',
#  'Snhg3',
#  'Lpcat1',
#  'Gm28891',
#  'Gm26807',
#  'Mfn2',
#  'Gm3587',
#  'Erg28',
#  'Zfp994',
#  'Prrxl1',
#  'Tmem170b',
#  'Gbp2',
#  'Gm35430',
#  'Rnf216',
#  'Stard5',
#  'Stard10',
#  'Taf1',
#  'Hook2',
#  'Slbp',
#  'Chsy3',
#  'Map1a',
#  'Cdc27',
#  'Gm16506',
#  'Gm47705',
#  'Zfp729a',
#  'Pard3',
#  '1700029F12Rik',
#  'BC065403',
#  'Bola3',
#  'Rad21l',
#  'Ihh',
#  'Gm21887',
#  'Gm17178',
#  'Vmn2r28',
#  'Ccp110',
#  'Tff3',
#  'Grik3',
#  'Tmem131',
#  'Stat2',
#  'Gm20395',
#  'Gm15461',
#  '1700041M19Rik',
#  'Gm27211',
#  'Gm47509',
#  'Gm44516',
#  'Blzf1',
#  'Gm28447',
#  'Olfr448',
#  'Atp7b',
#  'Vmn1r39',
#  'Pggt1b',
#  'Cacng4',
#  'Slco3a1',
#  'Acvr1c',
#  'Gm34276',
#  'Clrn1',
#  'Uqcrc2',
#  'Knop1',
#  'Olfr1344',
#  'Hnrnph2',
#  'Gm11454',
#  'Krt72',
#  'Xkr8',
#  'Lmo4',
#  'Mst1',
#  '2310061I04Rik',
#  'Nlrp4b',
#  'Nek8',
#  ...]

# %% [markdown]
# ## Save both previous and short genes on a collated list

# %%
import json

badGenes = list(np.unique([previousGenes + shortGenes]))

with open("../Data/badGenes.json", "w") as f:
    json.dump(badGenes, f, indent=4)

# %% [markdown]
# ## Do inverse, get a list of probable good genes

# %%
# Don't want to select from unsuitable genes, so load list of genes that are suspected to be unsuitable for MERSCOPE
with open("../Data/badGenes.json", "r") as f:
    badGenes = json.load(f)
    
# Find remaining genes after exclusion
keepGenes = list(set(gluData.var_names) - set(badGenes))

with open("../Data/keepGenes.json", "w") as f:
    json.dump(keepGenes, f, indent=4)

# %% [markdown]
# ## Misc Analysis

# %%
x.iloc[50000:50010,[0, 3, 4, 10]]
# Out:
#        seqname      start        end   gene_name
# 669158       6   90666713   90667811     Gm44123
# 669162       6   90770878   90771457     Gm44105
# 669166       6   90821963   90822442  Rpl21-ps12
# 669169       6   90834519   90834614     Gm25185
# 669172       6   90882801   90883435  Ppp1r2-ps2
# 669175       6  124835407  124840880      Gpr162
# 669190       6  124835410  124840675      Gpr162
# 669195       6  124835411  124840946      Gpr162
# 669212       6  124838694  124840675      Gpr162
# 669217       6  145061379  145120654       Irag2

# %%
z = x[x.gene_name == 'Nrxn1']
z.end - z.start
# Out:
# 1654644    1055276
# 1654691    1059427
# 1654742      52980
# 1654753    1053497
# 1654800     420072
# 1654817      52130
# 1654828     419589
# 1654847    1052057
# 1654895      51287
# 1654908    1051846
# 1654954     419054
# 1654973    1055837
# 1655020     171098
# 1655029     187055
# 1655034     246534
# 1655038     884515
# 1655057     226140
# 1655068     226048
# 1655079       2796
# 1655081     553277
# 1655095      40308
# 1655100     110580
# 1655107       9979
# 1655110     392840
# 1655115     389615
# 1655119       7295
# dtype: int64

# %%
z.iloc[:,8:]
# Out:
#                     gene_id gene_version gene_name     gene_source  \
# 1654644  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1654691  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1654742  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1654753  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1654800  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1654817  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1654828  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1654847  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1654895  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1654908  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1654954  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1654973  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1655020  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1655029  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1655034  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1655038  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1655057  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1655068  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1655079  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1655081  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1655095  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1655100  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1655107  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1655110  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1655115  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
# 1655119  ENSMUSG00000024109           19     Nrxn1  ensembl_havana
#
#            gene_biotype       transcript_id transcript_version  \
# 1654644  protein_coding  ENSMUST00000072671                 14
# 1654691  protein_coding  ENSMUST00000160844                 10
# 1654742  protein_coding  ENSMUST00000197268                  5
# 1654753  protein_coding  ENSMUST00000174331                  8
# 1654800  protein_coding  ENSMUST00000159778                  8
# 1654817  protein_coding  ENSMUST00000173917                  8
# 1654828  protein_coding  ENSMUST00000174337                  8
# 1654847  protein_coding  ENSMUST00000161402                 10
# 1654895  protein_coding  ENSMUST00000173222                  2
# 1654908  protein_coding  ENSMUST00000054059                 15
# 1654954  protein_coding  ENSMUST00000172466                  8
# 1654973  protein_coding  ENSMUST00000160800                  9
# 1655020  protein_coding  ENSMUST00000197104                  2
# 1655029  protein_coding  ENSMUST00000176918                  2
# 1655034  protein_coding  ENSMUST00000196269                  5
# 1655038  protein_coding  ENSMUST00000161102                  9
# 1655057  protein_coding  ENSMUST00000196559                  5
# 1655068  protein_coding  ENSMUST00000176118                  2
# 1655079  protein_coding  ENSMUST00000198899                  2
# 1655081  protein_coding  ENSMUST00000161637                  8
# 1655095  protein_coding  ENSMUST00000177342                  3
# 1655100  protein_coding  ENSMUST00000197224                  2
# 1655107  protein_coding  ENSMUST00000162227                  3
# 1655110  protein_coding  ENSMUST00000160467                  8
# 1655115  protein_coding  ENSMUST00000159419                  2
# 1655119  protein_coding  ENSMUST00000162002                  2
#
#         transcript_name transcript_source    transcript_biotype  \
# 1654644       Nrxn1-202            havana        protein_coding
# 1654691       Nrxn1-207            havana        protein_coding
# 1654742       Nrxn1-225            havana        protein_coding
# 1654753       Nrxn1-216            havana        protein_coding
# 1654800       Nrxn1-204            havana        protein_coding
# 1654817       Nrxn1-215            havana        protein_coding
# 1654828       Nrxn1-217    ensembl_havana        protein_coding
# 1654847       Nrxn1-209            havana        protein_coding
# 1654895       Nrxn1-214            havana        protein_coding
# 1654908       Nrxn1-201            havana        protein_coding
# 1654954       Nrxn1-213            havana        protein_coding
# 1654973       Nrxn1-206            havana        protein_coding
# 1655020       Nrxn1-223            havana        protein_coding
# 1655029       Nrxn1-219            havana  processed_transcript
# 1655034       Nrxn1-221            havana       retained_intron
# 1655038       Nrxn1-208            havana       retained_intron
# 1655057       Nrxn1-222            havana        protein_coding
# 1655068       Nrxn1-218            havana        protein_coding
# 1655079       Nrxn1-226            havana       retained_intron
# 1655081       Nrxn1-210            havana  processed_transcript
# 1655095       Nrxn1-220            havana  processed_transcript
# 1655100       Nrxn1-224            havana        protein_coding
# 1655107       Nrxn1-212            havana       retained_intron
# 1655110       Nrxn1-205            havana       retained_intron
# 1655115       Nrxn1-203            havana       retained_intron
# 1655119       Nrxn1-211            havana       retained_intron
#
#                                                        tag  \
# 1654644                                              basic
# 1654691                                         CCDS,basic
# 1654742                                         CCDS,basic
# 1654753                                              basic
# 1654800                                         CCDS,basic
# 1654817                                         CCDS,basic
# 1654828                                         CCDS,basic
# 1654847                                              basic
# 1654895                                              basic
# 1654908                                              basic
# 1654954                                         CCDS,basic
# 1654973                                         CCDS,basic
# 1655020  cds_end_NF,cds_start_NF,mRNA_end_NF,mRNA_start_NF
# 1655029
# 1655034
# 1655038
# 1655057                         cds_start_NF,mRNA_start_NF
# 1655068  cds_end_NF,cds_start_NF,mRNA_end_NF,mRNA_start_NF
# 1655079
# 1655081
# 1655095                                        mRNA_end_NF
# 1655100  cds_end_NF,cds_start_NF,mRNA_end_NF,mRNA_start_NF
# 1655107
# 1655110
# 1655115
# 1655119
#
#         transcript_support_level exon_number exon_id exon_version    ccds_id  \
# 1654644                        5
# 1654691                        1                                   CCDS57113
# 1654742                        3                                   CCDS84339
# 1654753                        5
# 1654800                        5                                   CCDS84340
# 1654817                        2                                   CCDS84338
# 1654828                        5                                   CCDS84341
# 1654847                        5
# 1654895                        1
# 1654908                        5
# 1654954                        5                                   CCDS84342
# 1654973                        1                                   CCDS57112
# 1655020                        5
# 1655029                        5
# 1655034                        5
# 1655038                        2
# 1655057                        3
# 1655068                        5
# 1655079                       NA
# 1655081                        1
# 1655095                        5
# 1655100                        5
# 1655107                        1
# 1655110                        1
# 1655115                        1
# 1655119                        1
#
#         protein_id protein_version
# 1654644
# 1654691
# 1654742
# 1654753
# 1654800
# 1654817
# 1654828
# 1654847
# 1654895
# 1654908
# 1654954
# 1654973
# 1655020
# 1655029
# 1655034
# 1655038
# 1655057
# 1655068
# 1655079
# 1655081
# 1655095
# 1655100
# 1655107
# 1655110
# 1655115
# 1655119

# %%
z.iloc[:,8:]
# Out:
#                    gene_id gene_version gene_name     gene_source  \
# 108722  ENSMUSG00000036907           12     C1ql2  ensembl_havana
#
#           gene_biotype       transcript_id transcript_version transcript_name  \
# 108722  protein_coding  ENSMUST00000037286                 12       C1ql2-201
#
#        transcript_source transcript_biotype         tag  \
# 108722    ensembl_havana     protein_coding  CCDS,basic
#
#        transcript_support_level exon_number exon_id exon_version    ccds_id  \
# 108722                        1                                   CCDS15233
#
#        protein_id protein_version
# 108722

# %%
geneDF = df[df.feature == "gene"]
geneDF["length"] = geneDF.end - geneDF.start
print(len(geneDF))
print(sum(geneDF["length"] < 3000))
# Out:
# 55414
# 26736
# C:\Users\mathew.summers\AppData\Local\Temp\ipykernel_13536\4003160007.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   geneDF["length"] = geneDF.end - geneDF.start
